# %%
import numpy as np
from scipy import linalg as la
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
N = 1000
x_1  = np.random.normal( 0, 1, N )
x_2  = x_1 + np.random.normal( 0, 3, N )
x_3  = 2*x_1 + x_2 
data = np.array([x_1, x_2, x_3])
C = np.cov(data)
L, V = la.eig(C)
print (L)
print(np.real_if_close(L))
print(V)
# Out:
# [2.65744209e+01+0.j 1.03314331e-15+0.j 2.02840490e+00+0.j]
# [2.65744209e+01 1.03314331e-15 2.02840490e+00]
# [[-0.1083172  -0.81649658  0.56709851]
#  [-0.58623378 -0.40824829 -0.69975945]
#  [-0.80286819  0.40824829  0.43443757]]

# %%
n = 3
U, spectrum, Vt = la.svd(C)

print ("Eigenvalues :",spectrum,'\n')
print("Eigenvectors :")
print (U,'\n')
print("Percent of the total dataset's variability explained by the principal components:" , 
      (spectrum[0] + spectrum[1]) / (spectrum[0] + spectrum[1]+ spectrum[2]) )

#pca
l, V = np.linalg.eig(C)
Lambda=np.diag(l)
#print (Lambda)
print ("A.trace():", C.trace())
print ("Lambda.trace():", Lambda.trace())
print("Lambda/ trace :")
print (Lambda/Lambda.trace())
# Out:
# Eigenvalues : [2.65744209e+01 2.02840490e+00 1.18296532e-15]
#
# Eigenvectors :
# [[-0.1083172   0.56709851 -0.81649658]
#  [-0.58623378 -0.69975945 -0.40824829]
#  [-0.80286819  0.43443757  0.40824829]]
#
# Percent of the total dataset's variability explained by the principal components: 1.0
# A.trace(): 28.602825749087998
# Lambda.trace(): 28.60282574908801
# Lambda/ trace :
# [[9.29083759e-01 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 3.61203232e-17 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 7.09162414e-02]]

# %%
datap = np.dot(V0.T, data)
datap
# Out:
# array([[ 2.74372805e+00,  6.70773907e+00,  9.45581323e-01, ...,
#          1.08413258e+01,  3.72809450e+00,  3.15962971e+00],
#        [ 1.81608469e-16,  8.48258703e-16, -1.41785847e-16, ...,
#         -2.03028342e-16, -3.17245952e-16, -9.72751191e-16],
#        [ 1.85202348e-01, -2.52771078e-01,  3.53363088e-01, ...,
#          1.28914068e+00,  1.14106144e+00,  2.31759171e+00]])

# %%
fig, plt1= plt.subplots( nrows = 2, ncols = 3, figsize = (16, 12) )
# the original data distribution
# a scale factor to emphazise the lines 
scale_factor=0.5

plt1[0,0].scatter(data[0,:], data[1,:], marker = 'o', alpha=0.2)
plt1[0,0].set_ylabel('$x_{0}$'.format(1))
plt1[0,0].set_xlabel('$x_{0}$'.format(2))
# draw each eigenvector
for li, vi in zip(l, V.T):
    plt1[0,0].plot([0, scale_factor*li*vi[0]], [0, scale_factor*li*vi[1]], 'r-', lw=2)

plt1[0,1].scatter(data[0,:], data[2,:], alpha=0.2)
plt1[0,1].set_ylabel('$x_{0}$'.format(1))
plt1[0,1].set_xlabel('$x_{0}$'.format(2))
# draw each eigenvector
for li, vi in zip(l, V.T):
    plt1[0,1].plot([0, scale_factor*li*vi[0]], [0, scale_factor*li*vi[2]], 'r-', lw=2)

plt1[0,2].scatter(data[1,:], data[2,:], alpha=0.2)
plt1[0,2].set_ylabel('$x_{0}$'.format(1))
plt1[0,2].set_xlabel('$x_{0}$'.format(2))
# draw each eigenvector
for li, vi in zip(l, V.T):
    plt1[0,2].plot([0, scale_factor*li*vi[1]], [0, scale_factor*li*vi[2]], 'r-', lw=2)
    
plt1[1,0].scatter(data[0,:], data[1,:], marker = 'o', alpha=0.2)
plt1[1,0].set_ylabel('$x_{0}$'.format(1))
plt1[1,0].set_xlabel('$x_{0}$'.format(2))
# draw each eigenvector
for li, vi in zip(l, np.diag([1]*3)):
    plt1[1,0].plot([0, scale_factor*li*vi[0]], [0, scale_factor*li*vi[1]], 'r-', lw=2)

plt1[1,1].scatter(data[0,:], data[2,:], alpha=0.2)
plt1[1,1].set_ylabel('$x_{0}$'.format(1))
plt1[1,1].set_xlabel('$x_{0}$'.format(2))
# draw each eigenvector
for li, vi in zip(l, np.diag([1]*3)):
    plt1[1,1].plot([0, scale_factor*li*vi[0]], [0, scale_factor*li*vi[2]], 'r-', lw=2)

plt1[1,2].scatter(data[1,:], data[2,:], alpha=0.2)
plt1[1,2].set_ylabel('$x_{0}$'.format(1))
plt1[1,2].set_xlabel('$x_{0}$'.format(2))
# draw each eigenvector
for li, vi in zip(l, np.diag([1]*3)):
    plt1[1,2].plot([0, scale_factor*li*vi[1]], [0, scale_factor*li*vi[2]], 'r-', lw=2)

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
std = 50 **(-1)
data_noise = np.random.normal(scale = std, size=(N, 10))
data_new   = np.concatenate((data.T, data_noise), axis = 1)

U, spectrum, V = np.linalg.svd(data_new.T)
lsvd = spectrum**2/(N-1)
Vsvd = U

print('eigenvalues : ', lsvd)
print('eigenvectors: ', Vsvd)

m = np.argsort(l)[::-1]
l = l[m]
tot  = (l[0] + l[1]) / l.sum()
print("Percent of the total dataset's variability explained by the principal components:" , tot)

Lambda = np.diag(l)
print(Lambda)
print("A.trace():", np.cov(data_new).trace())
print("Lambda.trace():", Lambda.trace())

print("Lambda/ trace :")
print(Lambda/Lambda.trace())
# Out:
# eigenvalues :  [2.65920400e+01 2.02986457e+00 4.84816259e-04 4.66264327e-04
#  4.32499595e-04 4.21898806e-04 4.03305291e-04 3.87098904e-04
#  3.79573733e-04 3.57150094e-04 3.51513181e-04 3.46228646e-04
#  3.48938708e-32]
# eigenvectors:  [[-1.08200205e-01  5.67120401e-01 -1.41021187e-04  5.76651160e-05
#   -1.44242874e-04  1.96364892e-04 -2.14288405e-04  1.53103288e-04
#   -7.53219922e-05 -1.85745305e-04  1.55569596e-04 -5.32740316e-04
#    8.16496581e-01]
#  [-5.86378066e-01 -6.99637844e-01  2.92119574e-04 -9.18505932e-05
#    4.60762210e-05 -3.46493938e-04  3.10644573e-04 -7.13652891e-05
#    2.33653359e-05  2.46289434e-04 -3.86139948e-04  6.75140314e-04
#    4.08248290e-01]
#  [-8.02778477e-01  4.34602957e-01  1.00771999e-05  2.34796387e-05
#   -2.42409528e-04  4.62358467e-05 -1.17932236e-04  2.34841288e-04
#   -1.27278649e-04 -1.25201176e-04 -7.50007557e-05 -3.90340318e-04
#   -4.08248290e-01]
#  [-1.35213132e-04  1.38455213e-04 -7.61120872e-03 -6.48689373e-01
# ...

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
