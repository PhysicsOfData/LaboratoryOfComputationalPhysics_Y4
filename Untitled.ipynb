# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from scipy import fftpack
import seaborn as sns
# %matplotlib inline
np.random.seed(12567)

# %%
df=pd.read_csv('run_000260_global.csv')
df.describe()
# Out:
#        event_number  number_hits  hit_1_chamber  hit_1_layer  hit_1_xright  \
# count   8182.000000  8182.000000    4833.000000  4833.000000   4833.000000
# mean    4224.366781     5.466879       1.430995   705.491517    -89.984300
# std     2439.329348     7.886049       0.988053   311.579491    477.518421
# min        1.000000     0.000000       0.000000     0.000000   -938.300000
# 25%     2115.250000     0.000000       0.000000   823.500000   -389.300000
# 50%     4223.500000     3.000000       2.000000   849.500000   -324.090000
# 75%     6337.750000     8.000000       2.000000   862.500000    382.100000
# max     8450.000000    78.000000       3.000000   862.500000    994.183170
#
#        hit_1_xleft  hit_2_chamber  hit_2_layer  hit_2_xright  hit_2_xleft  \
# count  4833.000000    4512.000000  4512.000000   4512.000000  4512.000000
# mean    -99.827724       1.527261   706.037566   -137.340172  -150.858690
# ...

# %%
#We need to select 'good' events, to do so, we require hits either on the
#left side (corrisponding to detector 0 and 1) or the right side (detectior 2 and 3).

# %%
df=pd.read_csv('run_000260_local.csv')
df.describe()
# Out:
#        event_number  number_hits  hit_1_chamber  hit_1_layer  hit_1_xleft  \
# count   8182.000000  8182.000000    4833.000000  4833.000000  4833.000000
# mean    4224.366781     5.466879       1.430995     2.251190   285.706460
# std     2439.329348     7.886049       0.988053     1.087163   224.220642
# min        1.000000     0.000000       0.000000     1.000000     0.016830
# 25%     2115.250000     0.000000       0.000000     1.000000    79.080000
# 50%     4223.500000     3.000000       2.000000     2.000000   225.500000
# 75%     6337.750000     8.000000       2.000000     3.000000   513.300000
# max     8450.000000    78.000000       3.000000     4.000000   671.800000
#
#        hit_1_xright  hit_2_chamber  hit_2_layer  hit_2_xleft  hit_2_xright  \
# count   4833.000000    4512.000000  4512.000000  4512.000000   4512.000000
# mean     295.549884       1.527261     2.632314   268.842521    282.361039
# std      224.264384       0.959920     1.117068   218.763432    220.290792
# ...
