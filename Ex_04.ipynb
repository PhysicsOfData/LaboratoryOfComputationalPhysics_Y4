# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import random

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
with open("simple_data.txt", "w") as file:
    file.write(str([random.random() for i in range(10)]))

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
a = [[random.random() for i in range(5)] for e in range(5)]
mat = np.matrix(a)

with open('data.txt','wb') as f:
    for line in mat:
        np.savetxt(f, line, fmt='%.2f')

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
read_file = pd.read_csv (r'data.txt')
read_file.to_csv (r'converted_data.csv', index=None)

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with  open('credit_card.dat','r') as file:
    
    c=0
    for line in file:
        Number=[]
        for n in range(19):
            dec=int("".join(line[(6*n):(6*(n+1))]),2)
            each_char= chr(dec)
            Number.append(each_char)
        
        print(Number,"\n")
        c+=1
        if c==50: break
# Out:
# ['7', '6', '4', '8', ' ', '5', '6', '7', '3', ' ', '3', '7', '7', '5', ' ', '2', '2', '7', '1']
#
# ['3', '2', '5', '7', ' ', '8', '2', '4', '7', ' ', '3', '3', '5', '4', ' ', '2', '2', '6', '6']
#
# ['2', '7', '2', '2', ' ', '0', '0', '0', '1', ' ', '4', '0', '1', '1', ' ', '6', '6', '5', '2']
#
# ['0', '6', '6', '1', ' ', '3', '0', '6', '3', ' ', '3', '7', '4', '2', ' ', '3', '1', '5', '0']
#
# ['0', '4', '3', '2', ' ', '1', '6', '0', '8', ' ', '1', '4', '6', '2', ' ', '4', '7', '4', '2']
#
# ['5', '8', '2', '7', ' ', '2', '0', '2', '7', ' ', '8', '7', '8', '5', ' ', '7', '3', '0', '3']
#
# ['5', '7', '7', '4', ' ', '8', '5', '2', '8', ' ', '2', '0', '8', '7', ' ', '1', '1', '1', '7']
#
# ['8', '1', '4', '0', ' ', '1', '2', '1', '0', ' ', '6', '3', '5', '2', ' ', '2', '8', '4', '5']
#
# ['5', '7', '6', '4', ' ', '1', '1', '3', '3', ' ', '7', '3', '0', '1', ' ', '7', '1', '0', '0']
#
# ['6', '4', '5', '6', ' ', '1', '7', '3', '7', ' ', '4', '1', '2', '6', ' ', '6', '7', '2', '6']
#
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import pandas as pd

data = json.load(open('user_data.json'))
filtered_data=[line for line in data if line.get('CreditCardType') == "American Express" ]
df = pd.DataFrame(data=filtered_data)
df.to_csv("user_data_filtered.csv", sep=',',index=False)

print(df)
# Out:
#      ID               JobTitle                       EmailAddress  \
# 0     2    Investment  Advisor       Clint_Thorpe5003@bulaffy.com
# 1    12         Retail Trainee   Phillip_Carpenter9505@famism.biz
# 2    28        Project Manager        Russel_Graves1378@extex.org
# 3    39            Stockbroker       Leanne_Newton1268@typill.biz
# 4    57         Budget Analyst          Tony_Giles1960@iatim.tech
# 5    62           CNC Operator        Owen_Allcott5125@bauros.biz
# 6    68        Project Manager           Liam_Lynn3280@kideod.biz
# 7    74                Dentist      Regina_Woodcock5820@yahoo.com
# 8    81          HR Specialist       Carter_Wallace9614@atink.com
# 9    92    Staffing Consultant           Maia_Stark2797@jiman.org
# 10   97            Stockbroker          Ciara_Lomax982@bauros.biz
# 11  116    Staffing Consultant      Isabel_Ellwood1475@fuliss.net
# 12  148           CNC Operator  Abdul_Townend2202@infotech44.tech
# ...

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import matplotlib.pyplot as plt
url= "https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
pf= pd.read_csv(url)

plt.hist(list(pf['class']), bins='auto')
plt.show()

print("It seems There are two classes for mushrooms which are eigther 1 or 1")
# Out:
# It seems There are two classes for mushrooms which are eigther 1 or 1

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url="https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
pf=pd.read_csv(url)

pf.plot.scatter("features_1","features_2", alpha= 0.5)
pf.plot.scatter("features_1","features_3", alpha= 0.5)
pf.plot.scatter("features_2","features_3", alpha= 0.5)
# Out:
# <AxesSubplot:xlabel='features_2', ylabel='features_3'>

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
url= "https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
df= pd.read_csv(url)

df.to_json (r'mushrooms_categorized_json.json')
df= pd.read_json(r'mushrooms_categorized_json.json')
