# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
# set the seed
np.random.seed(456)
# generate random numbers
random_numbers = np.random.rand(10)
print(random_numbers)
# saving random numbers into a txt file

# using python file I/O (not fun)
# with open("simple_data.txt","w") as file:
#     file.write(str(random_numbers))

# using numpy (or pandas) functions (fun)
np.savetxt("simple_data.txt", random_numbers)
# Out:
# [0.24875591 0.16306678 0.78364326 0.80852339 0.62562843 0.60411363
#  0.8857019  0.75911747 0.18110506 0.15016932]

# %%
# check if the above cell worked correctly
# !cat .\simple_data.txt
# Out:
# 2.487559093571017899e-01
# 1.630667831863564787e-01
# 7.836432556412277206e-01
# 8.085233888414787851e-01
# 6.256284278232958629e-01
# 6.041136332754238891e-01
# 8.857019031149135913e-01
# 7.591174678329831726e-01
# 1.811050561412440585e-01
# 1.501693161428389045e-01

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
# generate random numbers
random_matrix = np.random.rand(5, 5)
print(random_matrix)
# saving random numbers into a txt file


# using python file I/O (not fun)
# with open("data.txt","w") as file:
#     file.write(str(random_matrix))

# using numpy (or pandas) functions (fun)
np.savetxt("data.txt", random_matrix)
# Out:
# [[0.43567937 0.38527255 0.57570987 0.14609069 0.68659302]
#  [0.46880401 0.56999915 0.64570101 0.72334064 0.68067076]
#  [0.18091714 0.11815848 0.2427344  0.00818342 0.3600685 ]
#  [0.14604175 0.54272306 0.85710344 0.20021216 0.13463346]
#  [0.21359356 0.97315565 0.85832979 0.53378532 0.43445859]]

# %%
# !cat .\data.txt
# Out:
# 4.356793711439582717e-01 3.852725526500896391e-01 5.757098698077492971e-01 1.460906944566332522e-01 6.865930187051551004e-01
# 4.688040050612287679e-01 5.699991476659644896e-01 6.457010148048536458e-01 7.233406440863501263e-01 6.806707599795607244e-01
# 1.809171394037925040e-01 1.181584834964634068e-01 2.427343955343681525e-01 8.183416121430697743e-03 3.600684977113348673e-01
# 1.460417453061660931e-01 5.427230570313438252e-01 8.571034377480242217e-01 2.002121645848741194e-01 1.346334587012333328e-01
# 2.135935606486695226e-01 9.731556538429635417e-01 8.583297869224262300e-01 5.337853219096339030e-01 4.344585909891222064e-01

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
# ok let's do it by hand then... using the python file I/O...

# load the data by opening the file in read-only mode
with open("data.txt", "r") as f:
    # iterate over rows to load them
    rows = [line for line in f] 
    
# get the length of the first axis to make the code more general
n_rows = len(rows)
    # initialize an empty list to store the entries of the matrix
entries = []  

# create a new file in write mode
with open("data.csv", "w") as w:
    # now iterate over the rows to extract the entries
    for row in rows:  
        # split the string i.e. instead of having one big list 
        # we now create n_rows lists so each list corresponds to a row
        true_row = row.split()
        # let's join the list using a comma to separate the entries
        # I hope it is by hand enough... 
        # otherwise we would have to replace " " blank spaces with "," commas
        comma_row = ",".join(true_row)
        # write the row and add the line feed character to terminate the row
        w.write(comma_row + '\n')

# %%
# !cat .\data.csv
# Out:
# 4.356793711439582717e-01,3.852725526500896391e-01,5.757098698077492971e-01,1.460906944566332522e-01,6.865930187051551004e-01
# 4.688040050612287679e-01,5.699991476659644896e-01,6.457010148048536458e-01,7.233406440863501263e-01,6.806707599795607244e-01
# 1.809171394037925040e-01,1.181584834964634068e-01,2.427343955343681525e-01,8.183416121430697743e-03,3.600684977113348673e-01
# 1.460417453061660931e-01,5.427230570313438252e-01,8.571034377480242217e-01,2.002121645848741194e-01,1.346334587012333328e-01
# 2.135935606486695226e-01,9.731556538429635417e-01,8.583297869224262300e-01,5.337853219096339030e-01,4.344585909891222064e-01

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
# open the binary file in read-only mode
with open("credit_card.dat","r") as f:
    # get the first line
    first_line = next(f) 
    # get the characters of the first line
    chars = np.array([char for char in first_line])
    # for each line in the file
    for line in f:
        # if the length of the line is equals to the one of the first line
        if len(line) == len(first_line):
            # then append to the chars array the chars of the new line 
            chars = np.vstack((chars, np.array([char for char in line])))       

# initialize the empty list for credit card numbers
cc_numbers = []  
# for each binary cc number
for i in range(len(chars)):
    # create an empty list that will contain the entire card number
    cc_number = ""
    # here we start looking for the relevant bits
    for j in range( int( np.size(chars, 1) / 6 ) ):
        # n will contain the character in binary
        n = ""
        # load the relevant bits into n
        for k in range(6):
            n += chars[i, (6*j) + k] 
        # convert the binary into decimal
        c = chr( int(n, 2) ) 
        # add the decimal number to the credit card number string (as char)
        cc_number += c
    # append the credit card number to the credit card number list
    cc_numbers.append(cc_number)
    print(cc_number)
# print(cc_numbers)

# I probably missed an easier way of doing this... 
# too many for loops imo
# Out:
# 7648 5673 3775 2271
# 3257 8247 3354 2266
# 2722 0001 4011 6652
# 0661 3063 3742 3150
# 0432 1608 1462 4742
# 5827 2027 8785 7303
# 5774 8528 2087 1117
# 8140 1210 6352 2845
# 5764 1133 7301 7100
# 6456 1737 4126 6726
# 1228 8631 7382 0000
# 7051 0160 5374 3166
# 0618 3587 1630 6376
# 1545 5454 7444 5636
# 6735 3116 3202 6834
# 7287 5011 1547 8413
# 7033 2607 3328 4200
# 2568 5244 1874 5024
# 1684 2253 7570 7118
# 0672 2576 0575 6631
# 6332 8353 8787 1340
# 1813 3361 1175 4211
# 2477 6450 8840 2368
# 5512 3505 2563 1326
# 3083 7882 0621 0025
# 4521 5148 8045 0334
# 7563 3654 8713 5787
# 8324 2664 0476 5561
# 0565 2504 7168 3510
# 5107 5507 1767 0738
# 2462 1821 2448 1443
# 2788 0638 6861 6554
# 5851 5873 5474 0547
# 0670 1004 4013 2655
# 5874 5506 3048 0806
# 2805 5401 8462 1260
# 5083 8406 6310 1862
# 1076 1445 3013 2266
# 8440 4804 4844 5277
# 4758 6141 0686 1387
# 7586 0675 0315 2568
# 2544 1258 7432 5165
# 3474 5023 4434 5626
# 1410 0270 0434 5086
# 7315 4446 1104 4215
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import csv

# we need this function to format the csv nicely
def get_size(fileobject):
    """returns the size of a file"""
    fileobject.seek(0,2) # move the cursor to the end of the file
    size = fileobject.tell()
    return size

# define file names
input_file = "user_data.json"
output_file = "user_data.csv"

# read the json file
with open(input_file, "r") as f:
    data = json.load(f)

# filter data
filtered_data = [user for user in data if user['CreditCardType'] == 'American Express']

# open the output file in write mode
with open(output_file, "w") as w:
    # get the key names
    for name in filtered_data[0].keys():
        # write the keys only in the first row
        w.write("{},".format(name))
    # get the size of the file
    fsize = get_size(w)
    # delete the last character (the comma at the end of the line)
    w.truncate(fsize - 1)
    # and write a new line character instead
    w.write("\n")
    
    # for each user in the list
    for user in filtered_data:
        # for each key in its dict
        for key in user.keys():
            # write to file the values 
            w.write("{},".format(user[key]))
        # get the size of the file
        fsize = get_size(w)
        # delete the comma at the end of the line
        w.truncate(fsize - 1)
        # and write a new line character instead
        w.write("\n")

# %%
# !type .\user_data.csv
# Out:
# ID,JobTitle,EmailAddress,FirstNameLastName,CreditCard,CreditCardType
# 2,Investment  Advisor,Clint_Thorpe5003@bulaffy.com,Clint Thorpe,7083-8766-0251-2345,American Express
# 12,Retail Trainee,Phillip_Carpenter9505@famism.biz,Phillip Carpenter,3657-0088-0820-5247,American Express
# 28,Project Manager,Russel_Graves1378@extex.org,Russel Graves,6718-4818-8011-6024,American Express
# 39,Stockbroker,Leanne_Newton1268@typill.biz,Leanne Newton,5438-0816-4166-4847,American Express
# 57,Budget Analyst,Tony_Giles1960@iatim.tech,Tony Giles,8130-3425-7573-7745,American Express
# 62,CNC Operator,Owen_Allcott5125@bauros.biz,Owen Allcott,4156-0107-7210-2630,American Express
# 68,Project Manager,Liam_Lynn3280@kideod.biz,Liam Lynn,7152-3247-6053-2233,American Express
# 74,Dentist,Regina_Woodcock5820@yahoo.com,Regina Woodcock,0208-1753-3870-8002,American Express
# 81,HR Specialist,Carter_Wallace9614@atink.com,Carter Wallace,4256-7201-6717-4322,American Express
# ...

# %%
# with the formatting we've done two cells above, we could now easly load the csv file using pandas
# and it would be formatted as a dataframe!
df = pd.read_csv("user_data.csv", index_col="ID")
df
# Out:
#                   JobTitle                       EmailAddress  \
# ID
# 2      Investment  Advisor       Clint_Thorpe5003@bulaffy.com
# 12          Retail Trainee   Phillip_Carpenter9505@famism.biz
# 28         Project Manager        Russel_Graves1378@extex.org
# 39             Stockbroker       Leanne_Newton1268@typill.biz
# 57          Budget Analyst          Tony_Giles1960@iatim.tech
# 62            CNC Operator        Owen_Allcott5125@bauros.biz
# 68         Project Manager           Liam_Lynn3280@kideod.biz
# 74                 Dentist      Regina_Woodcock5820@yahoo.com
# 81           HR Specialist       Carter_Wallace9614@atink.com
# 92     Staffing Consultant           Maia_Stark2797@jiman.org
# 97             Stockbroker          Ciara_Lomax982@bauros.biz
# 116    Staffing Consultant      Isabel_Ellwood1475@fuliss.net
# 148           CNC Operator  Abdul_Townend2202@infotech44.tech
# 150             Fabricator        Caleb_Poulton1735@atink.com
# ...

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
file_name = "https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data = pd.read_csv(file_name)
data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
data.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
import seaborn as sns
from matplotlib.ticker import MaxNLocator

for feature in data.columns:
    fig, ax = plt.subplots(figsize=(7,5))
    sns.histplot(data[feature], discrete=True, edgecolor="white", ax=ax)
    ax.set_title(f"feature = {feature}")
    ax.set_xlabel(feature)
    ax.set_ylabel("counts")
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.show()

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
file_name="https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
data=pd.read_csv(file_name)
data
# Out:
#            label  features_1  features_2  features_3  features_4  features_5  \
# 0     -89.243497    2.175170   -0.285786   -0.603396   -0.627453   -0.686474
# 1     230.050125    1.481941   -1.327870   -0.543583   -0.303578    1.552964
# 2    -286.844411   -1.154394   -0.178649   -1.636646    0.239353   -0.684994
# 3     364.552862    0.197665    1.455707    1.562205    2.168207    0.053335
# 4     515.460006    0.596676    0.969860    1.294158   -0.404728    2.145297
# ...          ...         ...         ...         ...         ...         ...
# 1995 -328.100239   -1.820929    1.358539   -2.494838    0.828299    0.199255
# 1996  -62.960036   -0.883712   -0.063687   -0.418704   -0.872601    0.363769
# 1997  -90.262252   -0.021394   -0.312864   -0.730848   -1.341482   -0.720862
# 1998  -74.333901   -0.041909   -0.862731   -1.232011    1.268843    0.093043
# 1999    8.321454   -1.056364    0.259247    0.307835    1.094903    0.472395
#
# ...

# %%
color = sns.color_palette([sns.color_palette("tab10", 10)[0]])

g1 = sns.JointGrid(data=data, x="features_1", y="features_2")
g1.plot_joint(sns.scatterplot, s=80)
g1.plot_marginals(sns.histplot, kde=True, edgecolor="white", color=color)

g2 = sns.JointGrid(data=data, x="features_1", y="features_3")
g2.plot_joint(sns.scatterplot, s=80)
g2.plot_marginals(sns.histplot, kde=True, edgecolor="white", color=color)

g3 = sns.JointGrid(data=data, x="features_2", y="features_3")
g3.plot_joint(sns.scatterplot, s=80)
g3.plot_marginals(sns.histplot, kde=True, edgecolor="white", color=color)

plt.show()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
file_name = "https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data = pd.read_csv(file_name)
data.to_json('./data_task8.json')

# %%
# ah... windows....
# !sed -n 1,10p .\data_task8.json
# Out:
# "sed" non Š riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.
