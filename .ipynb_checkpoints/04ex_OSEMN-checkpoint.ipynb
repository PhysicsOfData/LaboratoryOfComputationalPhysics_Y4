# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
rand=np.random.rand(10)
file=open("simple_data.txt",'w')
file.write("\n".join([str(z) for z in rand]))
file.close()

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
rand=np.random.rand(5,5)
print(rand)
file=open("data.txt",'w')
for i in range(len(rand)):
    file.write("\t".join([str(z) for z in rand[i]]))
    file.write('\n')
file.close()
# Out:
# [[0.08991337 0.02440242 0.21163389 0.63537267 0.71792683]
#  [0.84754382 0.0042627  0.57678827 0.96961156 0.70095616]
#  [0.65575177 0.22225263 0.78978774 0.46904269 0.60062875]
#  [0.46506129 0.82776917 0.63395842 0.98330313 0.96045496]
#  [0.73214169 0.73428011 0.20404698 0.40302858 0.16119026]]

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import csv
file1=open("data.txt",'r')
file2=open("data.csv",'w')
csv_writer=csv.writer(file2,delimiter=',')
for line in file1:
    t=line.split('\t')
    print(t)
    csv_writer.writerow(t)
file1.close()
file2.close()

# don't know why, but the csv file created show only the first line (using excel to open it). However, clicking on the 2nd, 3rd, ... row then the lines saved in the file will be showed
# Out:
# ['0.08991337067107419', '0.024402420167750072', '0.21163389280208145', '0.6353726715591115', '0.717926826177985\n']
# ['0.8475438228810555', '0.004262699043920293', '0.5767882664105318', '0.9696115625993849', '0.7009561592108982\n']
# ['0.6557517702704467', '0.22225262701838744', '0.7897877362327697', '0.4690426917482273', '0.6006287523362\n']
# ['0.46506129253887873', '0.8277691683006647', '0.6339584167525364', '0.9833031331637078', '0.9604549617767592\n']
# ['0.7321416880297857', '0.7342801117415696', '0.2040469837966481', '0.4030285838452121', '0.1611902569161826\n']

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
file=open("credit_card.dat",'rb')
file_content=file.readlines()
word_size=6
out=[]
for j in range(len(file_content)-1):
    list_number=[]
    for i in range(0,len(file_content[0]),word_size):
        list_number.append(chr(int(file_content[j][i:i+word_size],2)))
    out.append("".join(list_number))
for i in range(len(out)):
        print(out[i])
file.close()
# Out:
# 7648 5673 3775 2271
#
# 3257 8247 3354 2266
#
# 2722 0001 4011 6652
#
# 0661 3063 3742 3150
#
# 0432 1608 1462 4742
#
# 5827 2027 8785 7303
#
# 5774 8528 2087 1117
#
# 8140 1210 6352 2845
#
# 5764 1133 7301 7100
#
# 6456 1737 4126 6726
#
# 1228 8631 7382 0000
#
# 7051 0160 5374 3166
#
# 0618 3587 1630 6376
#
# 1545 5454 7444 5636
#
# 6735 3116 3202 6834
#
# 7287 5011 1547 8413
#
# 7033 2607 3328 4200
#
# 2568 5244 1874 5024
#
# 1684 2253 7570 7118
#
# 0672 2576 0575 6631
#
# 6332 8353 8787 1340
#
# 1813 3361 1175 4211
#
# 2477 6450 8840 2368
#
# 5512 3505 2563 1326
#
# 3083 7882 0621 0025
#
# 4521 5148 8045 0334
#
# 7563 3654 8713 5787
#
# 8324 2664 0476 5561
#
# 0565 2504 7168 3510
#
# 5107 5507 1767 0738
#
# 2462 1821 2448 1443
#
# 2788 0638 6861 6554
#
# 5851 5873 5474 0547
#
# 0670 1004 4013 2655
#
# 5874 5506 3048 0806
#
# 2805 5401 8462 1260
#
# 5083 8406 6310 1862
#
# 1076 1445 3013 2266
#
# 8440 4804 4844 5277
#
# 4758 6141 0686 1387
#
# 7586 0675 0315 2568
#
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import csv
json_file=open('user_data.json')
file1=json.load(json_file)
file2=open('user_data_filtered.csv','w')

csv_writer=csv.writer(file2,delimiter=',')
columns=['ID','JobTitle','EmailAddress','FirstNameLastName','CreditCard','CreditCardType']
csv_writer.writerow(columns)

for i in range(len(file1)):
    if file1[i]['CreditCardType']=='American Express':
        data=[file1[i]['ID'],file1[i]['JobTitle'],file1[i]['EmailAddress'],file1[i]['FirstNameLastName'],file1[i]['CreditCard'],file1[i]['CreditCardType']]
        csv_writer.writerow(data)
json_file.close()
file2.close()

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import pandas as pd
import matplotlib.pyplot as plt
file=pd.read_csv('https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1')
print(file)
plt.hist(file['class'])

# I see that half of the mushrooms are of type '0' and the other half is of type '1'. This dataset is probably used to implement
 # machine learning algorithm for binary classification of the mushroom type.
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
file=pd.read_csv('https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1')

plt.plot(file['features_1'],file['features_2'],'.')
plt.xlabel('features_1')
plt.ylabel('features_2')
plt.show()

plt.plot(file['features_1'],file['features_3'],'.')
plt.xlabel('features_1')
plt.ylabel('features_3')
plt.show()

plt.plot(file['features_2'],file['features_3'],'.')
plt.xlabel('features_2')
plt.ylabel('features_3')
# Out:
# Text(0, 0.5, 'features_3')

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
file=pd.read_csv('https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1')
file.to_json('Mushrooms.json',orient='records')
