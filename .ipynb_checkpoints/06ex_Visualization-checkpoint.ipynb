# %% [markdown]
# 1\. **Kernel Density Estimate**
#
# Produce a KDE for a given distribution (by hand, not using seaborn!):
#
# * Fill a numpy array, x,  of len(N) (with N=O(100)) with a variable normally distributed, with a given mean a standard deviation
# * Fill an histogram in pyplot taking properly care about the aesthetic
#    * use a meaningful number of bins
#    * set a proper y axis label
#    * set proper value of y axis major ticks labels (e.g. you want to display only integer labels)
#    * display the histograms as data points with errors (the error being the poisson uncertainty)
# * for every element of x, create a gaussian with the mean corresponding the element value and std as a parameter that can be tuned. The std default value should be:
# $$ 1.06 * x.std() * x.size ^{-\frac{1}{5.}} $$
# you can use the scipy function `stats.norm()` for that.
# * In a separate plot (to be placed beside the original histogram), plot all the gaussian functions so obtained
# * Sum (with np.sum()) all the gaussian functions and normalize the result such that the integral matches the integral of the original histogram. For that you could use the `scipy.integrate.trapz()` method

# %%
import sys
import scipy as sp
import numpy as np
import random as ra
import matplotlib.pyplot as plt

#seed = ra.randrange(sys.maxsize)
seed = 47012742550741688
ra.seed(seed)
print("Seed was:", seed)

mean = 0
std = 3
N = 600
x = []
for i in range(N):
    x.append(ra.gauss(mean,std))
x = np.array(x)

fig = plt.figure()
hist = plt.hist(x,bins = 12, color = 'g')
y = hist[0]
binEdge = hist[1]


#fig, ax = plt.subplot()

bincenters = 0.5 * (binEdge[1:]+binEdge[:-1])
binwidth = binEdge[1]-binEdge[0]
error = (1/y)**(1/2)
plt.title('My Beautiful Histogram')
plt.ylabel('Frequency Sampled')
plt.xlabel('Gaussian Sampled Values')
plt.xticks(ticks = bincenters, labels = np.floor(bincenters))
plt.errorbar(bincenters,y, yerr = error, color = 'r',fmt='.k')
plt.show()

G = []
for i in range(N):
    val = []
    for j in range(N):
        val.append(ra.gauss(x[i],(1.06*std*(N**(-1/5)))))
    G.append(val)

#to hold frequency list of each historgam for a future sum
Gsum = []
    
#plt.hist(G[1])
fig2 = plt.figure()
plt.title('Fire From Within\n600 Gaussians in one Plot, Each Gaussian is Translucent')
plt.xlabel('Gaussian Sampled Values')
plt.ylabel('Frequency Sampled')
for i in range(N):
    if i < N/2:
        freq = plt.hist(G[i],bins = 12, color = (1/(i+1),0.3,0,0.6))
    if i > N/2:
        freq = plt.hist(G[i],bins = 12, color = (0,1/(i+1),0.6,0.01))
    Gsum.append(freq[0])
#Sum and normalise

#Gsum = np.array(Gsum)
Gsum = np.sum(Gsum, axis = 0)
Gnorm = Gsum/N

#for i in range(N):
 #   Gsum = Gsum+G[i]
  #  print(Gsum[20],G[i][20])
#Gsum = np.array(Gsum)
#Gnorm = Gsum/N
fig3 = plt.figure()
plt.title('I cheated on My Beautiful Histogram with this one\nThe 600 histograms above were averaged to create this one')
plt.ylabel('Frequency Sampled')
plt.xlabel('Gaussian Sampled Values')
plt.xticks(ticks = bincenters, labels = np.floor(bincenters))
plt.bar(bincenters, Gnorm, width = binwidth , color = 'b')
# Out:
# Seed was: 47012742550741688

# %%
help()
# Out:
# Welcome to Python 3.8's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.8/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".

# %% [markdown]
# 2\. **Color-coded scatter plot**
#
# Produce a scatter plot out of a dataset with two categories
#
# * Write a function that generate a 2D datasets of 2 categories. Each category should distribute as a 2D gaussian with a given mean and std (clearly it is better to have different values means..)
# * Display the dataset in a scatter plot marking the two categories with different marker colors.
#
# An example is given below
#
# You can try to make the procedure more general by allowing a given number $n\ge 2$ of categories

# %%
import random as ra
ra.seed(300)
n =1000
Ncat = 3
fig4 = plt.figure(figsize = (12.0,12.0))
for i in range(Ncat):
    meanx = ra.randrange(-10,10,1)
    meany = ra.randrange(-10,10,1)
    std = ra.randrange(1,4,1)
    x = []
    y = []
    for j in range(n):
        x.append(ra.gauss(meanx,std))
        y.append(ra.gauss(meany,std))
    plt.scatter(x,y, color = (1/(i+1),0,0.5,0.2), marker = 'o')

plt.title('My Pretty Clusters')
plt.xlabel('x value, sampled from a gaussian dist')  
plt.ylabel('y value, sampled from a gaussian dist')
plt.axis('equal')
plt.show()

# %%
! wget https://www.dropbox.com/s/u4y3k4kk5tc7j46/two_categories_scatter_plot.png
from IPython.display import Image
Image('two_categories_scatter_plot.png')
# Out:
# --2021-12-04 15:43:10--  https://www.dropbox.com/s/u4y3k4kk5tc7j46/two_categories_scatter_plot.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.66.18, 2620:100:6020:18::a27d:4012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.66.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/u4y3k4kk5tc7j46/two_categories_scatter_plot.png [following]
# --2021-12-04 15:43:10--  https://www.dropbox.com/s/raw/u4y3k4kk5tc7j46/two_categories_scatter_plot.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc827f28f7d56e9e5d245b0f1ff8.dl.dropboxusercontent.com/cd/0/inline/BbN1WWzRcaOSptiMWpN-YVP1HgBCbssBUiIt-TjKeOmhYLIANoqxSpAFE8go6-ddj6AvEL6O4RQSa7PfhSwqEIurFXrT4SWMI8i0Q2vr3UhKVb1E8DQ1pSBXF-ozRn8ch_-kvh2HTbrZ1EfCGz5RkYZG/file# [following]
# ...

# %% [markdown]
# 3\. **Profile plot**
#
# Produce a profile plot from a scatter plot.
# * Download the following dataset and load it as a pandas dataframe:
# ```bash
# wget https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.npy
# ```
# Note that you should use the `np.load()` function to load the file as a numpy array, call the `.item()` method, and then pass it to the `pd.DataFrame()` constructor.
# * Inspect the dataset, you'll find two variables (features)
# * Clean the sample by selecting the entries (rows) with the variable "residual" in absolute value smaller than 2
# * perform a linear regression of "residuals" versus "distances" using `scipy.stats.linregress()`
# * plot a seaborn jointplot of  "residuals" versus "distances", having seaborn performing a linear regression. The result of the regression should be displayed on the plot
# * Fill 3 numpy arrays
#   * x, serving as an array of bin centers for the "distance" variable. It should range from 0 to 20 with reasonable number of steps (bins)
#   * y, the mean values of the "residuals", estimated in slices (bins) of "distance"
#   * erry, the standard deviation of the  of the "residuals", estimated in slices (bins) of "distance"
# * Plot the profile plot on top of the scatter plot

# %%
# !wget https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.npy
# Out:
# --2021-12-06 20:03:35--  https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.npy
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/hgnvyj9abatk8g6/residuals_261.npy [following]
# --2021-12-06 20:03:36--  https://www.dropbox.com/s/raw/hgnvyj9abatk8g6/residuals_261.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc48121712cf30cdd660e9966c6e.dl.dropboxusercontent.com/cd/0/inline/BbWiOzfTeEfH3dZ8P-_wf8DZgkWORPkh_jjNLpl3UkKwuweRz-MzMdHp5VQHHmzV7c7kJcHAT94xc0W79g_FTwUXdy2rMgZYPWd3nf7Y_A85YQPI6YArpuWe0pd2fpQkVuWJAMrIlcr1ZLisJ_8xlQvY/file# [following]
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import linregress as lin
import matplotlib.pyplot as plt
import seaborn as sns

da = np.load('residuals_261.npy',allow_pickle =True)

df = pd.DataFrame(da.item())

#Clean the Data
df = df[np.abs(df['residuals'])<2]

#Perform Linear Regression with scipy.stats.linregress
m, c, _, _, _= lin(df['distances'],df['residuals'])

fig1 = plt.figure(figsize = (12,12))
plt.scatter(df['distances'],df['residuals'])
plt.axline((0,c),slope = m, color = 'g')

#plot a seaborn jointplot of "residuals" versus "distances", having seaborn performing a linear regression.
sns.jointplot(df['distances'], df['residuals'], kind = 'reg', joint_kws={'line_kws':{'color':'red'}})

# creation of x, y and erry
x = np.arange(0,20,1)
y = []
erry = []
for i in range(len(x)):
    under = df[df['distances'] < x[i]+.5]
    inbin = under[under['distances'] > x[i]-.5]
    y.append(inbin['residuals'].mean())
    erry.append(inbin['residuals'].std())
    
y = np.array(y)
erry = np.array(erry)

plt.figure(fig1.number)
plt.scatter(x,y,color = 'r')
plt.errorbar(x,y,yerr = erry, color = 'r',fmt = 'none',size = (12,12))
plt.xlabel('residules')
plt.ylabel('distances')
# Out:
# /home/daniel/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'distances')
