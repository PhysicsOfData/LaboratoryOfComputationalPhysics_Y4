# %% [markdown]
# 1\. Write a function that converts number representation (bin<->dec<->hex)

# %%
#1
def bin_dec_hex(number):
    B = int(number,2)
    C = hex(B)
     
    return B, C   

number = input("Enter binary:")
B,C = bin_dec_hex(number)
print("decimal number is:",B) 
print("hexadecimal number is:", C)
# Out:
# Enter binary:110011
# decimal number is: 51
# hexadecimal number is: 0x33

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
def bin_fun(k):
    binary = str()
    while (k):
        k *= 2
        if (k >= 1):
            int_part = 1
            k -= 1
        else:
            int_part = 0
        binary += str(int_part)

    return binary


def fun(n):

    if(n < 0):
        s = 0  #represent sign 
    else:
        s = 1
        
    n = abs(n)
    j = bin(int(n))[2 : ]
    fract = bin_fun(n - int(n))
    ind = j.index('1')
    e = bin((len(j) - ind - 1) + 127)[2 : ] #the exponent 
    
    m = j[ind + 1 : ] + fract + ("0"* (23 - len(j[ind + 1 : ] + fract))) #manstisa


    return s, e, m



s, exp, mant = fun(2.540000) #largest number 
print("Sign: " + str(s) + " | " + "exponent: " + exp + " | " + "mantissa: " + mant)
# Out:
# Sign: 1 | exponent: 10000000 | mantissa: 010001010001111010111000010100011110101110000101001

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
#3
# to determine the underflow and over limits for python on my computer 
factor = 2
n = 5000
x = 1  #underflow limits
y = 1  #overflow limits 
for i in range(n):
    x = x / 2  #to determine the n times x will be reducible
    y = y * 2  #to determine the n number y will double 
    print(i, "\t", "%2.2e" %x, "\t", "%2.2e" %y)
# Out:
# 0 	 5.00e-01 	 2.00e+00
# 1 	 2.50e-01 	 4.00e+00
# 2 	 1.25e-01 	 8.00e+00
# 3 	 6.25e-02 	 1.60e+01
# 4 	 3.12e-02 	 3.20e+01
# 5 	 1.56e-02 	 6.40e+01
# 6 	 7.81e-03 	 1.28e+02
# 7 	 3.91e-03 	 2.56e+02
# 8 	 1.95e-03 	 5.12e+02
# 9 	 9.77e-04 	 1.02e+03
# 10 	 4.88e-04 	 2.05e+03
# 11 	 2.44e-04 	 4.10e+03
# 12 	 1.22e-04 	 8.19e+03
# 13 	 6.10e-05 	 1.64e+04
# 14 	 3.05e-05 	 3.28e+04
# 15 	 1.53e-05 	 6.55e+04
# 16 	 7.63e-06 	 1.31e+05
# 17 	 3.81e-06 	 2.62e+05
# 18 	 1.91e-06 	 5.24e+05
# 19 	 9.54e-07 	 1.05e+06
# 20 	 4.77e-07 	 2.10e+06
# 21 	 2.38e-07 	 4.19e+06
# 22 	 1.19e-07 	 8.39e+06
# 23 	 5.96e-08 	 1.68e+07
# 24 	 2.98e-08 	 3.36e+07
# 25 	 1.49e-08 	 6.71e+07
# 26 	 7.45e-09 	 1.34e+08
# 27 	 3.73e-09 	 2.68e+08
# 28 	 1.86e-09 	 5.37e+08
# 29 	 9.31e-10 	 1.07e+09
# 30 	 4.66e-10 	 2.15e+09
# 31 	 2.33e-10 	 4.29e+09
# 32 	 1.16e-10 	 8.59e+09
# 33 	 5.82e-11 	 1.72e+10
# 34 	 2.91e-11 	 3.44e+10
# 35 	 1.46e-11 	 6.87e+10
# 36 	 7.28e-12 	 1.37e+11
# ...

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
# 4 (a)
n = 60
eps = 1 #machine precision 
for i in range(n):
    if i < n:
        i = i + 1
    eps = eps/2.0
    one_eps = eps + 1.0
print("one plus esp is :", one_eps)
print("eps is:", eps)
# Out:
# one plus esp is : 1.0
# eps is: 8.673617379884035e-19

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
# 5
import cmath
def quadratic(a,b,c):
    #quadratic formula
    #x = (-b ± (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    
    k = (b**2) - (4*a*c)
    
    # find two solutions
    x1 = (-b-cmath.sqrt(k))/(2*a)
    x2 = (-b+cmath.sqrt(k))/(2*a)
    
    return x1,x2
    
    

a = int(input("Enter a:"))
b = int(input("Enter b:"))
c = int(input("Enter c:"))
    
x1,x2 = quadratic(a,b,c)
print("Solutions of the equation are:")
print("X1 is:",x1)
print("X2 is:",x2)
# Out:
# Enter a:5
# Enter b:4
# Enter c:3
# Solutions of the equation are:
# X1 is: (-0.4-0.6633249580710799j)
# X2 is: (-0.4+0.6633249580710799j)

# %%
#5(a) using program to compute the solution for  𝑎=0.001 ,  𝑏=1000  and  𝑐=0.001

import cmath
def quadratic(a,b,c):
    #quadratic formula
    #x = (-b ± (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    
    k = (b**2) - (4*a*c)
    
    # find two solutions
    x1 = (-b-cmath.sqrt(k))/(2*a)
    x2 = (-b+cmath.sqrt(k))/(2*a)
    
    return x1,x2
    
a = 0.001
b = 1000
c = 0.001
    
x1,x2 = quadratic(a,b,c)
print("Solutions of the equation are:")
print("X1 is:",x1)
print("X2 is:",x2)
# Out:
# Solutions of the equation are:
# X1 is: (-999999.999999+0j)
# X2 is: (-9.999894245993346e-07+0j)

# %%
#5(b)
import cmath
def quadratic(a,b,c):
    #multiplying the quadratic formula top and botom by (-b ± (b ** 2 - 4 * a * c) ** 0.5) 
    #x = (-b ± (b ** 2 - 4 * a * c) ** 0.5) *(-b ± (b ** 2 - 4 * a * c) ** 0.5)/ (2 * a)*(-b ± (b ** 2 - 4 * a * c) ** 0.5)
    
    k = (b**2) - (4*a*c)
    
    #substituting k, we have
    # x = (-b ± (k) ** 0.5)*(-b ± (K) ** 0.5)/(2 * a)*(-b ± (k) ** 0.5)
    
    #further simplying we have
    
    # find two solutions
    x1 = ((-b-cmath.sqrt(k))*(-b-cmath.sqrt(k)))/((2*a)*(-b-cmath.sqrt(k)))
    x2 = ((-b+cmath.sqrt(k))*(-b+cmath.sqrt(k)))/((2*a)*(-b+cmath.sqrt(k)))
    
    return x1,x2
    
    

a = 0.001
b = 1000
c = 0.001
    
x1,x2 = quadratic(a,b,c)
print("Solutions of the equation are:")
print("X1 is:",x1)
print("X2 is:",x2)
# Out:
# Solutions of the equation are:
# X1 is: (-999999.999999-0j)
# X2 is: (-9.999894245993346e-07-0j)

# %%
# 5 (c)

import cmath

def quadratic(a,b,c):
    # using quadratic formula
    #x = (-b ± (b ** 2 - 4 * a * c) ** 0.5) / (2 * a)
    
    k = (b ** 2) - (4 * a * c)
    
    # find two solutions
    x1 = (- b - cmath.sqrt(k))/(2 * a)
    x2 = (- b + cmath.sqrt(k))/(2 * a)

    return x1,x2

a = float(input("Enter value of a:"))
b = float(input("Enter value of b:"))
c = float(input("Enter value of c:"))
    
x1,x2 = quadratic(a,b,c)
print("Solutions of the equation are:")
print("X1 is:",x1)
print("X2 is:",x2)
# Out:
# Enter value of a:5
# Enter value of b:3
# Enter value of c:2
# Solutions of the equation are:
# X1 is: (-0.3-0.5567764362830021j)
# X2 is: (-0.3+0.5567764362830021j)

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
#6a.I
# derivative of the function using df/dx definition 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

def func(x):
    return x*(x-1)
def func_der(x, a): #Let delta = a 
    return (func(x+a)-func(x))/a


x = int(input("Enter value for x:"))
a = float(input("Enter value for delta:"))
y =func_der(x,a)
print(y)
# Out:
# Enter value for x:1
# Enter value for delta:.01
# 1.010000000000001

# %%
#6a.II
# analytically derivative of the function f(x) 
#let dy/dx = y
def f(x):
    return 2*x - 1
z= f(1)

print("The actual value of dy/dx is:",z)
# Out:
# The actual value of dy/dx is: 1

# %%
#6a.III
error = (y - z)/z
print("The error is:", error)
# Out:
# The error is: 0.010000000000000897

# %% [markdown]
# With the given value 𝛿 that function return float value of 1 and an error of zero.

# %%
#6b.I

for i in range (4,16,2):
    y1=(func_der(1,1/(10**i)))
    error1  = (y1 - z)/z
    print(y1,'\t',error1)

print('The values of dy/dx\t corresponding errors')
# Out:
# 1.0000999999998899 	 9.999999988985486e-05
# 1.0000009999177333 	 9.99917733279787e-07
# 1.0000000039225287 	 3.922528746258536e-09
# 1.000000082840371 	 8.284037100736441e-08
# 1.0000889005833413 	 8.890058334132256e-05
# 0.9992007221626509 	 -0.0007992778373491216
# The values of dy/dx	 corresponding errors

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt(1-x^2) {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
#7a 
import math
import time
def func_tion(x):
    f = 1 - x*x
    return math.sqrt(f)

def rie_mann(a, b, N):
    h = 2/N
    y_k  = (func_tion(a) + func_tion(b))/2 
    for k in range (1, N):
        y_k += func_tion((a + (k-1)*h))
    y_k *= h
        
    return y_k

a = -1
b = 1
N = 100
# %timeit rie_mann(a, b, N)
# Out:
# 76.9 µs ± 1.51 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#comapring the result with true value
#let compute the percertange error or error value 
true_value = math.pi/2
computed_value = rie_mann(a, b, N)
error_value = (true_value - computed_value)/ true_value
print("The error value of the function is:", error_value)
# Out:
# The error value of the function is: 0.0035918221209400554

# %%
#let N = 10000
# %timeit rie_mann(-1, 1, 10000)
# Out:
# 7.68 ms ± 147 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
N_min = 60 * 10000
# %timeit v = rie_mann(-1, 1, N_min)
# Out:
# 486 ms ± 9.99 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
