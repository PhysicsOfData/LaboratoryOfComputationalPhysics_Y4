# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/
# Out:
# --2021-12-01 15:36:53--  https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/xvjzaxzz3ysphme/data_000637.txt [following]
# --2021-12-01 15:36:54--  https://www.dropbox.com/s/raw/xvjzaxzz3ysphme/data_000637.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc50d6cab194d87447bc7a2a83e3.dl.dropboxusercontent.com/cd/0/inline/BbA_PCeWBMTycSn_X3p7Bdp1UxOCtR6K1OWn2RwoEhP8lNz2B0BjdU75YOqAB2okHezD41oDU7gQ3k3arCt__2VzpB4o2_EYcGPwKXLHp5xCp8QiNUbepU-kXapM2CXh-KEKeHcvvkvTSFKP_VD9FqMs/file# [following]
# ...

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1.Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. 
#Choose N to be smaller than or equal to the maximum number of rows and larger that 10k
N = 12000

file_name = "/home/ale/data/data_000637.txt"
data=pd.read_csv(file_name,nrows=N)
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0         1     0          123  3869200167        2374        26
# 1         1     0          124  3869200167        2374        27
# 2         1     0           63  3869200167        2553        28
# 3         1     0           64  3869200167        2558        19
# 4         1     0           64  3869200167        2760        25
# ...     ...   ...          ...         ...         ...       ...
# 11995     1     0          139  3869200286        3251         0
# 11996     1     0           62  3869200286        3246         4
# 11997     1     0           58  3869200286        3246        11
# 11998     1     0           61  3869200286        3251        17
# 11999     1     0           59  3869200286        3248        16
#
# [12000 rows x 6 columns]

# %%
#2. Find out the number of BX in a ORBIT (the value 'x').

max_BX = data['BX_COUNTER'].max() 
min_BX = data['BX_COUNTER'].min() 
x = max_BX - min_BX +1
print("The value of x is:", x)
# Out:
# The value of x is: 3564

# %%
#3. Find out how much the data taking lasted. You can either make an estimate based on the fraction 
#of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.



print("The data taking lasted: ",
      (((data['ORBIT_CNT'].max()-total_['ORBIT_CNT'].min()) * x +(data.loc[N-1,'BX_COUNTER']))*25 + (data.loc[N-1, 'TDC_MEAS']-data.loc[0,'TDC_MEAS'])*25/30)*1e-9)
# Out:
# The data taking lasted:  0.010684091666666666

# %%
#4. Create a new column with the absolute time in ns 
# (as a combination of the other three columns with timing information).
data['TIME'] = (((data['ORBIT_CNT'] - data['ORBIT_CNT'].min()) * x + data['BX_COUNTER'])* 25 +
                             data['TDC_MEAS'] * (25/30)) 
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS          TIME
# 0         1     0          123  3869200167        2374        26  5.937167e+04
# 1         1     0          124  3869200167        2374        27  5.937250e+04
# 2         1     0           63  3869200167        2553        28  6.384833e+04
# 3         1     0           64  3869200167        2558        19  6.396583e+04
# 4         1     0           64  3869200167        2760        25  6.902083e+04
# ...     ...   ...          ...         ...         ...       ...           ...
# 11995     1     0          139  3869200286        3251         0  1.068418e+07
# 11996     1     0           62  3869200286        3246         4  1.068405e+07
# 11997     1     0           58  3869200286        3246        11  1.068406e+07
# 11998     1     0           61  3869200286        3251        17  1.068419e+07
# 11999     1     0           59  3869200286        3248        16  1.068411e+07
#
# ...

# %%
#5. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
data['HEAD'] = np.random.randint(0, 2, N)
data
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS      TIME
# 0         1     0          123  3869200167        2374        26  0.000059
# 1         0     0          124  3869200167        2374        27  0.000059
# 2         1     0           63  3869200167        2553        28  0.000064
# 3         1     0           64  3869200167        2558        19  0.000064
# 4         1     0           64  3869200167        2760        25  0.000069
# ...     ...   ...          ...         ...         ...       ...       ...
# 11995     0     0          139  3869200286        3251         0  0.010684
# 11996     0     0           62  3869200286        3246         4  0.010684
# 11997     0     0           58  3869200286        3246        11  0.010684
# 11998     0     0           61  3869200286        3251        17  0.010684
# 11999     1     0           59  3869200286        3248        16  0.010684
#
# [12000 rows x 7 columns]

# %%
#6.  Create a new DataFrame that contains only the rows with HEAD=1.

mask = data['HEAD'] == 1
data_new = data[mask]
data_new
# Out:
#        HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS      TIME
# 0         1     0          123  3869200167        2374        26  0.000059
# 2         1     0           63  3869200167        2553        28  0.000064
# 3         1     0           64  3869200167        2558        19  0.000064
# 4         1     0           64  3869200167        2760        25  0.000069
# 5         1     0           63  3869200167        2762         4  0.000069
# ...     ...   ...          ...         ...         ...       ...       ...
# 11985     1     1            1  3869200286        3014         3  0.010678
# 11986     1     0          123  3869200286        3008        26  0.010678
# 11987     1     0           57  3869200286        3014        22  0.010678
# 11994     1     0           57  3869200286        3246         4  0.010684
# 11999     1     0           59  3869200286        3248        16  0.010684
#
# [5967 rows x 7 columns]

# %%
#7. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel

mask_0 = data['FPGA'] == 0
mask_1 = data['FPGA'] == 1

data[mask_0].groupby('TDC_CHANNEL').count()['HEAD'].plot(label = "FPGA 1")
data[mask_1].groupby('TDC_CHANNEL').count()['HEAD'].plot(label = "FPGA 2")
plt.legend()
plt.show()

# %%
#8. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)

# %%
#9


data_orbit = data["ORBIT_CNT","TDC_CHANNEL"]
print(len(np.unique(data_orbit)))
mask = data["TDC_CHANNEL"] == 139
print(len(np.unique(data_orbit[mask])))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ORBIT_CNT', 'TDC_CHANNEL')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-7b9552d2e8a8> in <module>
#       2
#       3
# ...
