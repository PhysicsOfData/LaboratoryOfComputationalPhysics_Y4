# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
from scipy import linalg as la
from matplotlib import pyplot as plt
import pandas as pd

# %%
x1 = np.random.normal(0,1,1000)
x2 = x1+np.random.normal(0,3,1000)
x3 = 2*x1 + x2 

X = np.array((x1,x2,x3))

# %%
Cov_X = np.cov(X)

#la eig
l, V = la.eig(Cov_X)
print("Eigenvalues :",l,"\n","Eigenvectors :",V,"\n")

#SVD
U, spectrum, Vt = la.svd(X)
l_svd = spectrum**2/(1000-1)
V_svd = U
print("SVD eigenvalues: ",l_svd,"\n","SVD eigenvectors :",V_svd,"\n")

print("fist eigenvalue: ", np.real_if_close(l[0]/sum(l)))
print("second eigenvalue: ", np.real_if_close(l[1]/sum(l)))
print("third eigenvalue: ", np.real_if_close(l[2]/sum(l)),'\n')
# Out:
# Eigenvalues : [ 2.62784531e+01+0.j -2.98545888e-15+0.j  2.00454666e+00+0.j]
#  Eigenvectors : [[-0.11840127 -0.81649658  0.56507917]
#  [-0.57367655 -0.40824829 -0.71009052]
#  [-0.81047909  0.40824829  0.42006782]]
#
# SVD eigenvalues:  [2.62786127e+01 2.00476615e+00 2.85060448e-32]
#  SVD eigenvectors : [[-0.11840563  0.56507826 -0.81649658]
#  [-0.57367107 -0.71009495 -0.40824829]
#  [-0.81048233  0.42006157  0.40824829]]
#
# fist eigenvalue:  0.9291253873031489
# second eigenvalue:  -1.0555665610072642e-16
# third eigenvalue:  0.07087461269685126

# %%
#reduce dim (99% of total variability)
w = np.array([V_svd[0],V_svd[1]])
Xr = np.dot(w,X) 

#redefine data in the new base
Xp = np.dot(V_svd.T, X)

#plots
scale = 1
fig, ((p00,p01,p02),(p10,p11,p12)) = plt.subplots(nrows=2, ncols=3, figsize=(24, 14))

p00.scatter(X[0,:], X[1,:], alpha=0.4, color='y')
p01.scatter(X[0,:], X[2,:], alpha=0.4, color='b')
p02.scatter(X[1,:], X[2,:], alpha=0.4, color='g')
for li, vi in zip(l_svd, V_svd.T):
    p00.plot([0, scale*li*vi[0]], [0, scale*li*vi[1]], 'r-', lw=2)
    p01.plot([0, scale*li*vi[0]], [0, scale*li*vi[2]], 'r-', lw=2)
    p02.plot([0, scale*li*vi[1]], [0, scale*li*vi[2]], 'r-', lw=2.5)
p10.scatter(Xp[0,:], Xp[1,:], alpha=0.4, color='y')
p11.scatter(Xp[0,:], Xp[2,:], alpha=0.4, color='b')
p12.scatter(Xp[1,:], Xp[2,:], alpha=0.4, color='g')
for li, vi in zip(l_svd, np.diag([1,1,1])):
    p10.plot([0, scale*li*vi[0]], [0, scale*li*vi[1]], 'r-', lw=2)
    p11.plot([0, scale*li*vi[0]], [0, scale*li*vi[2]], 'r-', lw=2)
    p12.plot([0, scale*li*vi[1]], [0, scale*li*vi[2]], 'r-', lw=2.5)
    
p00.set_ylabel('Original', fontsize = 20)
p10.set_ylabel('New coordinates', fontsize = 20)
p00.set_title('x1 vs x2', fontsize = 20)
p01.set_title('x1 vs x3', fontsize = 20)
p02.set_title('x2 vs x3', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'x2 vs x3')

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
noise = abs(np.random.normal(0,(3/50),10))
value = np.random.randint(0,9)

new_x1 = x1 + np.random.normal(0,noise[value],1000)
new_x2 = x1+np.random.normal(0,3,1000)+np.random.normal(0,noise[value],1000)
new_x3 = 2*new_x1 + new_x2 

new_X = np.array((new_x1,new_x2,new_x3))

# %%
Cov_new_X = np.cov(new_X)

#la eig
l, V = la.eig(Cov_new_X)
print("Eigenvalues :",l,"\n","Eigenvectors :",V,"\n")

#SVD
U, spectrum, Vt = la.svd(new_X)
l_svd = spectrum**2/(1000-1)
V_svd = U
print("SVD eigenvalues: ",l_svd,"\n","SVD eigenvectors :",V_svd,"\n")

print("fist eigenvalue: ", np.real_if_close(l[0]/sum(l)))
print("second eigenvalue: ", np.real_if_close(l[1]/sum(l)))
print("third eigenvalue: ", np.real_if_close(l[2]/sum(l)),'\n')
# Out:
# Eigenvalues : [2.85131024e+01+0.j 2.39549939e-17+0.j 1.98806850e+00+0.j]
#  Eigenvectors : [[-0.11421494 -0.81649658  0.56594018]
#  [-0.57891739 -0.40824829 -0.70582433]
#  [-0.80734726  0.40824829  0.42605602]]
#
# SVD eigenvalues:  [2.85253243e+01 1.98809071e+00 2.33142641e-32]
#  SVD eigenvectors : [[-0.11420382  0.56594242 -0.81649658]
#  [-0.57893125 -0.70581296 -0.40824829]
#  [-0.8073389   0.42607187  0.40824829]]
#
# fist eigenvalue:  0.9348199283766808
# second eigenvalue:  7.853794863083743e-19
# third eigenvalue:  0.06518007162331924

# %%
#reduce dim (99% of total variability)
w = np.array([V_svd[0],V_svd[1]])
new_Xr = np.dot(w,new_X) 

#redefine data in the new base
new_Xp = np.dot(V_svd.T, new_X)

#plots
scale = 1
fig, ((p00,p01,p02),(p10,p11,p12)) = plt.subplots(nrows=2, ncols=3, figsize=(24, 14))

p00.scatter(new_X[0,:], new_X[1,:], alpha=0.4, color='y')
p01.scatter(new_X[0,:], new_X[2,:], alpha=0.4, color='b')
p02.scatter(new_X[1,:], new_X[2,:], alpha=0.4, color='g')
for li, vi in zip(l_svd, V_svd.T):
    p00.plot([0, scale*li*vi[0]], [0, scale*li*vi[1]], 'r-', lw=2)
    p01.plot([0, scale*li*vi[0]], [0, scale*li*vi[2]], 'r-', lw=2)
    p02.plot([0, scale*li*vi[1]], [0, scale*li*vi[2]], 'r-', lw=2.5)
p10.scatter(new_Xp[0,:], new_Xp[1,:], alpha=0.4, color='y')
p11.scatter(Xp[0,:], new_Xp[2,:], alpha=0.4, color='b')
p12.scatter(new_Xp[1,:], new_Xp[2,:], alpha=0.4, color='g')
for li, vi in zip(l_svd, np.diag([1,1,1])):
    p10.plot([0, scale*li*vi[0]], [0, scale*li*vi[1]], 'r-', lw=2)
    p11.plot([0, scale*li*vi[0]], [0, scale*li*vi[2]], 'r-', lw=2)
    p12.plot([0, scale*li*vi[1]], [0, scale*li*vi[2]], 'r-', lw=2.5)
    
p00.set_ylabel('Original', fontsize = 20)
p10.set_ylabel('New coordinates', fontsize = 20)
p00.set_title('new_x1 vs new_x2', fontsize = 20)
p01.set_title('new_x1 vs new_x3', fontsize = 20)
p02.set_title('new_x2 vs new_x3', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'new_x2 vs new_x3')

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
# Out:
# --2022-01-19 17:39:48--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Risoluzione di archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connessione a archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connesso.
# Richiesta HTTP inviata, in attesa di risposta... 200 OK
# Lunghezza: 1477391 (1,4M) [application/x-httpd-php]
# Salvataggio in: "/home/gaetano/data/magic04.data.1"
#
# magic04.data.1      100%[===================>]   1,41M   729KB/s    in 2,0s
#
# 2022-01-19 17:39:50 (729 KB/s) - "/home/gaetano/data/magic04.data.1" salvato [1477391/1477391]
#
# --2022-01-19 17:39:51--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names
# Risoluzione di archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connessione a archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connesso.
# Richiesta HTTP inviata, in attesa di risposta... 200 OK
# ...

# %%
file_name="~/data/magic04.data"
data=pd.read_csv(file_name, names=["fLength","fWidth","fSize","fConc","fConc1","fAsym","fM3Long","fM3Trans","fAlpha","fDist","classification"])
data=data[data['classification']=='g'] 
data=data.iloc[:,:-2].T
covm=np.cov(data)

lm, Vm = la.eig(covm)


#PCA 
dataPCA=np.dot(Vm.T, data)

dataPCA
# Out:
# array([[-3.59246302e+01, -4.10497223e+01, -8.79757082e+01, ...,
#         -2.50584273e+01, -6.36353909e+01, -4.78745680e+01],
#        [-2.24021533e+00, -1.29278672e+01,  2.43153844e+01, ...,
#         -8.28120576e+00,  5.12348767e+01, -2.70377234e+00],
#        [-2.31141721e+01,  2.71756060e-01,  7.73758069e+01, ...,
#         -1.25833500e+01,  5.77783433e+01, -4.00591047e+00],
#        ...,
#        [-1.74741622e+00, -1.55740490e+00,  1.15086159e+00, ...,
#         -1.50438532e+00, -1.80827334e+00, -1.86579964e+00],
#        [-1.33054711e+00, -1.51192212e+00, -1.49833880e+00, ...,
#         -1.37884021e+00, -1.36365126e+00, -1.36328779e+00],
#        [-1.04874167e-01, -2.98856003e-02, -9.56630626e-02, ...,
#         -9.98345755e-02, -8.74288077e-02, -1.00101230e-01]])
