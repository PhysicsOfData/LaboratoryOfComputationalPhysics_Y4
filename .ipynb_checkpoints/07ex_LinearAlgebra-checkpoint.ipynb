# %%
import numpy as np
import numpy.random as npr
from scipy import linalg as la
import matplotlib.pyplot as plt
import math as m
import pandas as pd

# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
npr.seed(2053854)

#1
x1=npr.normal(loc=0, scale=1, size=1000)
x2=x1+npr.normal(loc=0, scale=3, size=1000)
x3=2*x1+x2

M=np.array([x1,x2,x3])

#2
covM=np.cov(M)
print("Covariance matrix: \n{}\n".format(covM))
l, V = la.eig(covM)
print("Eigenvalues: \n {}".format(l.round(2)))
print("Eigenvectors: \n {}\n".format(V.round(3))) 

#3
U, spectrum, Vt = la.svd(M)
U[:,[1,2]]=U[:,[2,1]]
spectrum[[1,2]]=spectrum[[2,1]]


print("Eigenvalues with SVD: \n {}".format((spectrum**2/(len(x1-1))).round(2)))
print("Eigenvectors with SVD: \n {}\n".format(U.round(3)))

print("Verify that the eigenvectors coincide (with an accurancy of 0.01): {}".format(np.allclose(U.round(2), V.round(2))))
print("Verify that the eigenvalues coincide (with an accurancy of 0.1): {}\n".format(np.allclose((spectrum**2/len(x1-1)).round(1), (np.real_if_close(l)).round(1))))

#4
for i in range(len(l)):
    print("For eigenvalue {} the percent of the total dataset's variability is: {:.15f} %".format(i+1, 100*abs(np.real_if_close(l)[i]/sum(np.real_if_close(l)))))

print( "\nOnly two pricipal components (the first and the third) contain more then 99% of the total variability, in fact when the dataset was constructed x3 was a combination of x1 and x2 \n")
    

    
#5
Mp=np.dot(V.T, M)


#6
scale_factor=0.5

l=np.real_if_close(l)

fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3, figsize=(12, 7))

ax1.scatter(M[0,:], M[1,:], alpha=0.5)
ax1.plot([0,scale_factor*l[0]*V[0,0]], [0, scale_factor*l[0]*V[1,0]], c='g')
ax1.plot([0,scale_factor*l[1]*V[0,1]], [0, scale_factor*l[1]*V[1,1]], c='r') 
ax1.set_xlim(-15,15)
ax1.set_ylim(-15,15)
ax1.set_title("0 vs 1")

ax2.scatter(M[0,:], M[2,:], alpha=0.5)
ax2.plot([0,scale_factor*l[0]*V[0,0]], [0, scale_factor*l[0]*V[2,0]], c='g')
ax2.plot([0,scale_factor*l[2]*V[0,2]], [0, scale_factor*l[2]*V[2,2]], c='y')
ax2.set_xlim(-15,15)
ax2.set_ylim(-15,15)
ax2.set_title("0 vs 2")

ax3.scatter(M[1,:], M[2,:], alpha=0.5)
ax3.plot([0,scale_factor*l[1]*V[1,1]], [0, scale_factor*l[1]*V[2,1]], c='r')
ax3.plot([0,scale_factor*l[2]*V[1,2]], [0, scale_factor*l[2]*V[2,2]], c='y')
ax3.set_xlim(-15,15)
ax3.set_ylim(-15,15)
ax3.set_title("1 vs 2")

scale_factor=0.5

ax4.scatter(Mp[0,:], Mp[1,:], alpha=0.5)
ax4.plot([0,scale_factor*l[0]], [0, 0], c='g')
ax4.plot([0,0], [0, scale_factor*l[1]], c='r')
ax4.set_xlim(-15,15)
ax4.set_ylim(-15,15)
ax4.set_title("0 vs 1 PCA")

ax5.scatter(Mp[0,:], Mp[2,:], alpha=0.5)
ax5.plot([0,scale_factor*l[0]], [0, 0], c='g')
ax5.plot([0,0], [0, scale_factor*l[2]], c='y')
ax5.set_xlim(-15,15)
ax5.set_ylim(-15,15)
ax5.set_title("0 vs 2 PCA")

ax6.scatter(Mp[1,:], Mp[2,:], alpha=0.5)
ax6.plot([0,scale_factor*l[1]], [0, 0], c='r')
ax6.plot([0,0], [0, scale_factor*l[2]], c='y')
ax6.set_xlim(-15,15)
ax6.set_ylim(-15,15)
ax6.set_title("1 vs 2 PCA")

M1=M #for next exercise
Mp1=Mp
l1=l
# Out:
# Covariance matrix:
# [[ 1.06101944  0.89340007  3.01543894]
#  [ 0.89340007  9.53854268 11.32534281]
#  [ 3.01543894 11.32534281 17.3562207 ]]
#
# Eigenvalues:
#  [25.79+0.j -0.  +0.j  2.17+0.j]
# Eigenvectors:
#  [[-0.12  -0.816  0.565]
#  [-0.572 -0.408 -0.711]
#  [-0.811  0.408  0.418]]
#
# Eigenvalues with SVD:
#  [25.85  0.    2.17]
# Eigenvectors with SVD:
#  [[-0.12  -0.816  0.565]
#  [-0.572 -0.408 -0.712]
#  [-0.812  0.408  0.418]]
#
# Verify that the eigenvectors coincide (with an accurancy of 0.01): True
# Verify that the eigenvalues coincide (with an accurancy of 0.1): True
#
# For eigenvalue 1 the percent of the total dataset's variability is: 92.240870552052385 %
# For eigenvalue 2 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 3 the percent of the total dataset's variability is: 7.759129447947618 %
#
# Only two pricipal components (the first and the third) contain more then 99% of the total variability, in fact when the dataset was constructed x3 was a combination of x1 and x2

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
M=M1

for r in range(10):
    M=np.vstack([M,npr.normal(loc=0, scale=1/50, size=1000)])
    
print(M.shape)
covM=np.cov(M)
l, V = la.eig(covM)



for i in range(len(l)):
    print("For eigenvalue {} the percent of the total dataset's variability is: {:.15f} %".format(i+1, 100*abs(np.real_if_close(l)[i]/sum(np.real_if_close(l)))))


Mp=np.dot(V.T, M)


print("\nIt is possible to see that again the principal components are only 2 so by the PCA procedure we can reduce the problem to this 2 new cordinates and neglet the noise introduced")

scale_factor=0.5

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 7))

ax1.scatter(Mp1[0,:], Mp1[2,:], alpha=0.5)
ax1.plot([0,scale_factor*l1[0]], [0, 0], c='g')
ax1.plot([0,0], [0, scale_factor*l1[2]], c='y')
ax1.set_xlim(-15,15)
ax1.set_ylim(-15,15)
ax1.set_title("PCA without the noise")

ax2.scatter(Mp[0,:], Mp[1,:], alpha=0.5)
ax2.plot([0,scale_factor*l[0]], [0, 0], c='g')
ax2.plot([0,0], [0, scale_factor*l[1]], c='r')
ax2.set_xlim(-15,15)
ax2.set_ylim(-15,15)
ax2.set_title("PCA with the noise")
# Out:
# (13, 1000)
# For eigenvalue 1 the percent of the total dataset's variability is: 92.227751429767295 %
# For eigenvalue 2 the percent of the total dataset's variability is: 7.758040235262584 %
# For eigenvalue 3 the percent of the total dataset's variability is: 0.000000000000008 %
# For eigenvalue 4 the percent of the total dataset's variability is: 0.001666922979915 %
# For eigenvalue 5 the percent of the total dataset's variability is: 0.001629403102264 %
# For eigenvalue 6 the percent of the total dataset's variability is: 0.001579692684940 %
# For eigenvalue 7 the percent of the total dataset's variability is: 0.001223612563702 %
# For eigenvalue 8 the percent of the total dataset's variability is: 0.001238053588361 %
# For eigenvalue 9 the percent of the total dataset's variability is: 0.001280551218390 %
# For eigenvalue 10 the percent of the total dataset's variability is: 0.001343051698009 %
# For eigenvalue 11 the percent of the total dataset's variability is: 0.001378233783351 %
# For eigenvalue 12 the percent of the total dataset's variability is: 0.001435867857668 %
# For eigenvalue 13 the percent of the total dataset's variability is: 0.001432945493511 %
#
# It is possible to see that again the principal components are only 2 so by the PCA procedure we can reduce the problem to this 2 new cordinates and neglet the noise introduced
# /home/eugenio/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'PCA with the noise')

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %%
t=np.array(np.linspace(0,4*m.pi,100)) #time
x=np.cos(t)
y=np.zeros(100)+npr.normal(loc=0, scale=1/50, size=100)
z=np.zeros(100)

Mat=np.array([x, y, z])

fig=plt.figure(figsize=plt.figaspect(0.3))

#initial plot
aax1 = fig.add_subplot(1, 3, 1, projection='3d')
aax1.scatter(Mat[0], Mat[1], Mat[2])
aax1.set_title('Initial dataset in cartesian coordinates')


def MatRot(theta, phi):
    theta=theta*m.pi/180
    phi=phi*m.pi/180
    roty=np.array([[np.cos(phi),0,np.sin(phi)],[0, 1,0], [-np.sin(phi),0,np.cos(phi)]])
    rotz=np.array([[np.cos(theta),-np.sin(theta),0], [np.sin(theta),np.cos(theta),0],[0,0,1]])
    matrot=np.dot(rotz, roty)
    return matrot

theta=[10,20,30,45,50,70,75]
phi=[0,5,38,12,84,65,30]

totMat=[]


for thet, ph in zip(theta, phi):
    Matn=np.dot(MatRot(thet, ph),Mat)
    totMat.append(Matn[0])
    totMat.append(Matn[1])
    totMat.append(Matn[2])
    
#show that rotation works   
aax2 = fig.add_subplot(1, 3, 2, projection='3d')
aax2.scatter(Matn[0], Matn[1], Matn[2]) 
aax2.set_title('From camera at (\u03B8 = {}°, \u03C6 {}°)'.format(theta[-1], phi[-1]))


for a in (aax1,aax2):
    a.set_xlim(-1.1,1.1)
    a.set_ylim(-1.1,1.1)
    a.set_zlim(-1.1,1.1)
        
totMat=np.array(totMat)
totl, totV = la.eig(np.cov(totMat))

totl=np.real_if_close(totl)
print("Eigenvalues: {}".format(totl))
for i in range(len(totl)):
    print("For eigenvalue {} the percent of the total dataset's variability is: {:.15f} %".format(i+1, 100*abs(totl[i]/sum(totl))))

print("\nIt is possible to see again that just one eigenvalue contains more then 99% of the total variability. The second eigenvalue rapresent the variability in the cartesian y")

#PCA procedure
totMatp=np.dot(totV.T, totMat)
        
print("\nSo after the PCA procedure we have reduced the problem from {} to 1 principal component.".format(len(totMat)))



#plot the dataset in the principal component

scale_factor=0.5

fig1, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 7))

ax1.scatter(totMatp[0,:], totMatp[1,:], alpha=0.5)
ax1.plot([0,scale_factor*totl[0]], [0, 0], c='g')
ax1.plot([0,0], [0, scale_factor*totl[1]], c='r')
ax1.set_xlim(-3,3)
ax1.set_ylim(-3,3)
ax1.set_title("$x_p$ vs $2^{nd}$ direction by PCA")

ax2.scatter(t, totMatp[0,:])
ax2.set_ylabel("$x_p$")  #we have again a cosine
ax2.set_xlabel("time")
# Out:
# Eigenvalues: [ 3.57001736e+00  2.12567555e-03  5.30285794e-16 -4.46888945e-16
#   3.31813739e-16 -2.99560293e-16  1.77751331e-16 -1.44592367e-16
#  -1.44592367e-16 -2.57484334e-17 -2.57484334e-17  7.84888620e-17
#   7.84888620e-17 -4.41268288e-17  4.13088982e-17  2.81012010e-17
#  -1.15732204e-17 -5.74499076e-19 -1.44942565e-18  6.60864571e-18
#   0.00000000e+00]
# For eigenvalue 1 the percent of the total dataset's variability is: 99.940492988893141 %
# For eigenvalue 2 the percent of the total dataset's variability is: 0.059507011106869 %
# For eigenvalue 3 the percent of the total dataset's variability is: 0.000000000000015 %
# For eigenvalue 4 the percent of the total dataset's variability is: 0.000000000000013 %
# For eigenvalue 5 the percent of the total dataset's variability is: 0.000000000000009 %
# For eigenvalue 6 the percent of the total dataset's variability is: 0.000000000000008 %
# For eigenvalue 7 the percent of the total dataset's variability is: 0.000000000000005 %
# For eigenvalue 8 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 9 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 10 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 11 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 12 the percent of the total dataset's variability is: 0.000000000000002 %
# For eigenvalue 13 the percent of the total dataset's variability is: 0.000000000000002 %
# For eigenvalue 14 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 15 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 16 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 17 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 18 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 19 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 20 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 21 the percent of the total dataset's variability is: 0.000000000000000 %
#
# It is possible to see again that just one eigenvalue contains more then 99% of the total variability. The second eigenvalue rapresent the variability in the cartesian y
#
# So after the PCA procedure we have reduced the problem from 21 to 1 principal component.
# /home/eugenio/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# Text(0.5, 0, 'time')

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/

# %%
file_name="~/data/magic04.data"
data=pd.read_csv(file_name, names=["fLength","fWidth","fSize","fConc","fConc1","fAsym","fM3Long","fM3Trans","fAlpha","fDist","classification"])
data=data[data['classification']=='g']
data=data.iloc[:,:-2]
covm=np.cov(data)

lm, Vm = la.eig(covm)


print("Eigenvalues: {}".format(np.real_if_close(lm)))

for i in range(len(lm)):
    print("For eigenvalue {} the percent of the total dataset's variability is: {:.15f} %".format(i+1, 100*abs(np.real_if_close(lm)[i]/sum(np.real_if_close(lm)))))

    
dataPCA=np.dot(Vm.T, data)
# Out:
# Eigenvalues: [ 3.95235675e+06+0.00000000e+00j  2.06147810e+06+0.00000000e+00j
#   1.20860232e+06+0.00000000e+00j ... -2.57462750e-14+2.94338077e-14j
#  -2.57462750e-14-2.94338077e-14j -6.18413161e-15+0.00000000e+00j]
# For eigenvalue 1 the percent of the total dataset's variability is: 48.458745751572032 %
# For eigenvalue 2 the percent of the total dataset's variability is: 25.275209052236935 %
# For eigenvalue 3 the percent of the total dataset's variability is: 14.818336525720891 %
# For eigenvalue 4 the percent of the total dataset's variability is: 8.166332023685744 %
# For eigenvalue 5 the percent of the total dataset's variability is: 2.536672359491494 %
# For eigenvalue 6 the percent of the total dataset's variability is: 0.739825951782397 %
# For eigenvalue 7 the percent of the total dataset's variability is: 0.004830121917880 %
# For eigenvalue 8 the percent of the total dataset's variability is: 0.000048213592609 %
# For eigenvalue 9 the percent of the total dataset's variability is: 0.000000000000005 %
# For eigenvalue 10 the percent of the total dataset's variability is: 0.000000000000005 %
# For eigenvalue 11 the percent of the total dataset's variability is: 0.000000000000005 %
# For eigenvalue 12 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 13 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 14 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 15 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 16 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 17 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 18 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 19 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 20 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 21 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 22 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 23 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 24 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 25 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 26 the percent of the total dataset's variability is: 0.000000000000004 %
# For eigenvalue 27 the percent of the total dataset's variability is: 0.000000000000003 %
# For eigenvalue 28 the percent of the total dataset's variability is: 0.000000000000003 %
# For eigenvalue 29 the percent of the total dataset's variability is: 0.000000000000003 %
# For eigenvalue 30 the percent of the total dataset's variability is: 0.000000000000003 %
# For eigenvalue 31 the percent of the total dataset's variability is: 0.000000000000003 %
# For eigenvalue 32 the percent of the total dataset's variability is: 0.000000000000003 %
# For eigenvalue 33 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 34 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 35 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 36 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 37 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 38 the percent of the total dataset's variability is: 0.000000000000001 %
# For eigenvalue 39 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 40 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 41 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 42 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 43 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 44 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 45 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 46 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 47 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 48 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 49 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 50 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 51 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 52 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 53 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 54 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 55 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 56 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 57 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 58 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 59 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 60 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 61 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 62 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 63 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 64 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 65 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 66 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 67 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 68 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 69 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 70 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 71 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 72 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 73 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 74 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 75 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 76 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 77 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 78 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 79 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 80 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 81 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 82 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 83 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 84 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 85 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 86 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 87 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 88 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 89 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 90 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 91 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 92 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 93 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 94 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 95 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 96 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 97 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 98 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 99 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 100 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 101 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 102 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 103 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 104 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 105 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 106 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 107 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 108 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 109 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 110 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 111 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 112 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 113 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 114 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 115 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 116 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 117 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 118 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 119 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 120 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 121 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 122 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 123 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 124 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 125 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 126 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 127 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 128 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 129 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 130 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 131 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 132 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 133 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 134 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 135 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 136 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 137 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 138 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 139 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 140 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 141 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 142 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 143 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 144 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 145 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 146 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 147 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 148 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 149 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 150 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 151 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 152 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 153 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 154 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 155 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 156 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 157 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 158 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 159 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 160 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 161 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 162 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 163 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 164 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 165 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 166 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 167 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 168 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 169 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 170 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 171 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 172 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 173 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 174 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 175 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 176 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 177 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 178 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 179 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 180 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 181 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 182 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 183 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 184 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 185 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 186 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 187 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 188 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 189 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 190 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 191 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 192 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 193 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 194 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 195 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 196 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 197 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 198 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 199 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 200 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 201 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 202 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 203 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 204 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 205 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 206 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 207 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 208 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 209 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 210 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 211 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 212 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 213 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 214 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 215 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 216 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 217 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 218 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 219 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 220 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 221 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 222 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 223 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 224 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 225 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 226 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 227 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 228 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 229 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 230 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 231 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 232 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 233 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 234 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 235 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 236 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 237 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 238 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 239 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 240 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 241 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 242 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 243 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 244 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 245 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 246 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 247 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 248 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 249 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 250 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 251 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 252 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 253 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 254 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 255 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 256 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 257 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 258 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 259 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 260 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 261 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 262 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 263 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 264 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 265 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 266 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 267 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 268 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 269 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 270 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 271 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 272 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 273 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 274 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 275 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 276 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 277 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 278 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 279 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 280 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 281 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 282 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 283 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 284 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 285 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 286 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 287 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 288 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 289 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 290 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 291 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 292 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 293 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 294 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 295 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 296 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 297 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 298 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 299 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 300 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 301 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 302 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 303 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 304 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 305 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 306 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 307 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 308 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 309 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 310 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 311 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 312 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 313 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 314 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 315 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 316 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 317 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 318 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 319 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 320 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 321 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 322 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 323 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 324 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 325 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 326 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 327 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 328 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 329 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 330 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 331 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 332 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 333 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 334 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 335 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 336 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 337 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 338 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 339 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 340 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 341 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 342 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 343 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 344 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 345 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 346 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 347 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 348 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 349 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 350 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 351 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 352 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 353 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 354 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 355 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 356 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 357 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 358 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 359 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 360 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 361 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 362 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 363 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 364 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 365 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 366 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 367 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 368 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 369 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 370 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 371 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 372 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 373 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 374 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 375 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 376 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 377 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 378 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 379 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 380 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 381 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 382 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 383 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 384 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 385 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 386 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 387 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 388 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 389 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 390 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 391 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 392 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 393 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 394 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 395 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 396 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 397 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 398 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 399 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 400 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 401 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 402 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 403 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 404 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 405 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 406 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 407 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 408 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 409 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 410 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 411 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 412 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 413 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 414 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 415 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 416 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 417 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 418 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 419 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 420 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 421 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 422 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 423 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 424 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 425 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 426 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 427 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 428 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 429 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 430 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 431 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 432 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 433 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 434 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 435 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 436 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 437 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 438 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 439 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 440 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 441 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 442 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 443 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 444 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 445 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 446 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 447 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 448 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 449 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 450 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 451 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 452 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 453 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 454 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 455 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 456 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 457 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 458 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 459 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 460 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 461 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 462 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 463 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 464 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 465 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 466 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 467 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 468 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 469 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 470 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 471 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 472 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 473 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 474 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 475 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 476 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 477 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 478 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 479 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 480 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 481 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 482 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 483 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 484 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 485 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 486 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 487 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 488 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 489 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 490 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 491 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 492 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 493 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 494 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 495 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 496 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 497 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 498 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 499 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 500 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 501 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 502 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 503 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 504 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 505 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 506 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 507 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 508 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 509 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 510 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 511 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 512 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 513 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 514 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 515 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 516 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 517 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 518 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 519 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 520 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 521 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 522 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 523 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 524 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 525 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 526 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 527 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 528 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 529 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 530 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 531 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 532 the percent of the total dataset's variability is: 0.000000000000000 %
# ...
# For eigenvalue 12160 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12161 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12162 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12163 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12164 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12165 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12166 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12167 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12168 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12169 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12170 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12171 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12172 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12173 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12174 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12175 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12176 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12177 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12178 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12179 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12180 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12181 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12182 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12183 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12184 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12185 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12186 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12187 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12188 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12189 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12190 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12191 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12192 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12193 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12194 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12195 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12196 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12197 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12198 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12199 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12200 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12201 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12202 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12203 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12204 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12205 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12206 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12207 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12208 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12209 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12210 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12211 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12212 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12213 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12214 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12215 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12216 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12217 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12218 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12219 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12220 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12221 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12222 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12223 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12224 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12225 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12226 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12227 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12228 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12229 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12230 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12231 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12232 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12233 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12234 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12235 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12236 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12237 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12238 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12239 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12240 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12241 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12242 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12243 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12244 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12245 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12246 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12247 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12248 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12249 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12250 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12251 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12252 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12253 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12254 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12255 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12256 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12257 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12258 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12259 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12260 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12261 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12262 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12263 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12264 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12265 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12266 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12267 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12268 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12269 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12270 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12271 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12272 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12273 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12274 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12275 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12276 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12277 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12278 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12279 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12280 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12281 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12282 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12283 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12284 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12285 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12286 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12287 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12288 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12289 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12290 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12291 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12292 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12293 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12294 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12295 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12296 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12297 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12298 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12299 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12300 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12301 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12302 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12303 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12304 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12305 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12306 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12307 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12308 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12309 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12310 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12311 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12312 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12313 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12314 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12315 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12316 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12317 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12318 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12319 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12320 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12321 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12322 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12323 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12324 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12325 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12326 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12327 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12328 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12329 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12330 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12331 the percent of the total dataset's variability is: 0.000000000000000 %
# For eigenvalue 12332 the percent of the total dataset's variability is: 0.000000000000000 %
