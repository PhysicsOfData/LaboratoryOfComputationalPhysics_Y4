# %% [markdown]
# 1\. **PCA on 3D dataset**
#
# * Generate a dataset with 3 features each with N entries (N being ${\cal O}(1000)$). With $N(\mu,\sigma)$ the normali distribution with mean $\mu$ and $\sigma$  standard deviation, generate the 3 variables $x_{1,2,3}$ such that:
#     * $x_1$ is distributed as $N(0,1)$
#     * $x_2$ is distributed as $x_1+N(0,3)$
#     * $x_3$ is given by $2x_1+x_2$
# * Find the eigenvectors and eigenvalues of the covariance matrix of the dataset
# * Find the eigenvectors and eigenvalues using SVD. Check that the two procedures yield to same result
# * What percent of the total dataset's variability is explained by the principal components? Given how the dataset was constructed, do these make sense? Reduce the dimensionality of the system so that at least 99% of the total variability is retained.
# * Redefine the data in the basis yielded by the PCA procedure
# * Plot the data points in the original and the new coordiantes as a set of scatter plots. Your final figure should have 2 rows of 3 plots each, where the columns show the (0,1), (0,2) and (1,2) proejctions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import linalg as la

# %matplotlib inline

# %%
N = 2000
n_f = 3
x1 = np.random.normal(0,1,N)
x2 = x1 + np.random.normal(0,3,N)
x3 = 2*x1 + x2
data = np.array([x1,x2,x3])
cov = np.cov(data)
l, V = la.eig(cov)
l = np.real_if_close(l)
print("Eig method:\n")
print("The covariance matrix of the dataset is:\n",cov,'\n')
print("First eigenvalue: ", l[0], "with eigenvector: ", V[:,0])
print("Second eigenvalue: ", l[1], "with eigenvector: ", V[:,1])
print("Third eigenvalue: ", l[2], "with eigenvector: ", V[:,2])
# Out:
# Eig method
#
# The covariance matrix of the dataset is:
#  [[ 1.02065806  1.05921554  3.10053166]
#  [ 1.05921554 10.0456725  12.16410358]
#  [ 3.10053166 12.16410358 18.3651669 ]]
#
# First eigenvalue:  27.434463546495323 with eigenvector:  [-0.11813141 -0.57401558 -0.8102784 ]
# Second eigenvalue:  -4.973583611201574e-16 with eigenvector:  [-0.81649658 -0.40824829  0.40824829]
# Third eigenvalue:  1.9970339177580596 with eigenvector:  [ 0.56513565 -0.70981649  0.42045481]

# %%
U, spectrum, Vt = la.svd(data)
l_svd = spectrum**2/(N-1)
V_svd = U.T
print("SVD method:\n")
print("First eigenvalue: ", l_svd[0], "with eigenvector: ", V_svd[:,0])
print("Second eigenvalue: ", l_svd[1], "with eigenvector: ", V_svd[:,1])
print("Third eigenvalue: ", l_svd[2], "with eigenvector: ", V_svd[:,2])
# Out:
# SVD method:
#
# First eigenvalue:  27.43454674265448 with eigenvector:  [-0.11814391  0.56513304 -0.81649658]
# Second eigenvalue:  2.000839372775601 with eigenvector:  [-0.57399988 -0.70982919 -0.40824829]
# Third eigenvalue:  1.324762901763821e-31 with eigenvector:  [-0.8102877   0.42043689  0.40824829]

# %%
Lambda=np.diag(l)
print (Lambda)
print ("data.trace():", np.cov(cov).trace(),"\n")
print ("Lambda.trace():", Lambda.trace(),"\n")

print (Lambda[0,0]/Lambda.trace())
print (Lambda[1,1]/Lambda.trace())
print (Lambda[2,2]/Lambda.trace(),"\n")
print("The first and the second eigenvalues retain the",(Lambda[0,0]+Lambda[2,2])/Lambda.trace()*100,"% of the total variability")
Lambda = np.diag(l)
print("This makes sense because the x3 variable is a linar combination of x1 and x2")
ReducedLambda = np.delete(Lambda,(1), axis=1)
ReducedLambda = np.delete(ReducedLambda ,(1), axis=0)
print("Reduced matrix  of eigenvectors: \n", ReducedLambda)
# Out:
# [[2.44597191e+01 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 2.23242297e-15 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 1.96371361e+00]]
# data.trace(): 74.99382864414596
#
# Lambda.trace(): 26.423432697131926
#
# 0.925682872840169
# 8.448648585078083e-17
# 0.07431712715983077
#
# The first and the second eigenvalues retain the 99.99999999999999 % of the total variability
# This makes sense because the x3 variable is a linar combination of x1 and x2
# Reduced matrix  of eigenvectors:
#  [[24.45971909  0.        ]
#  [ 0.          1.96371361]]

# %%
U, spectrum, Vt = np.linalg.svd(data)
l_svd = spectrum**2/(N-1)
V_svd = U.T
Xp = np.dot(V_svd, data) 
X_reduced = np.array([Xp[0, :], Xp[1, :]])

fig, ((plt1, plt2,plt3),(plt4,plt5,plt6)) = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

plt1.scatter(data[0,:], data[1,:], alpha=0.2)
plt2.scatter(data[0,:], data[2,:], alpha=0.2, color = 'purple')
plt3.scatter(data[1,:], data[2,:], alpha=0.2, color = 'orange')
plt4.scatter(Xp[0,:], Xp[1,:], alpha=0.2)
plt5.scatter(Xp[0,:], Xp[2,:], alpha=0.2, color = 'purple')
plt6.scatter(Xp[1,:], Xp[2,:], alpha=0.2, color = 'orange')

plt1.set_ylabel("Original coordinates")
plt4.set_ylabel("New coordinates")
plt1.set_title('(0,1)')
plt2.set_title('(0,2)')
plt3.set_title('(1,2)')
# Out:
# Text(0.5, 1.0, '(1,2)')

# %% [markdown]
# 2\. **PCA on a nD dataset**
#
# Start from the dataset you have genereted in the previous exercise and add uncorrelated random noise. Such noise should be represented by other 10 uncorrelated variables normal distributed, with standar deviation much smaller (say, a factor 50) than those used to generate the $x_1$ and $x_2$.
#
# Repeat the PCA procedure and compare the results with what you obtained before

# %%
data_2 = np.array([x1,x2,x3])
n_var = 10
noises = np.zeros((n_var,N))
sigmas = [ np.random.randint(0,9)/50 for x in range(n_var)]
for i in range(0,10):
    noises[i,:] = np.random.normal(0.0, sigmas[i], N)
data_with_noises = np.vstack((data_2,noises))



U, spectrum, Vt = np.linalg.svd(data_with_noises)
l_svd = spectrum**2/(N-1)
V_svd = U.T
Xp = np.dot(V_svd, data_with_noises) 


for i in range(13):
    print("Eigenvalue", l_svd[i], "with eigenvector: ",V_svd[:,i] ,"\n")
Lambda = np.diag(l)
print((Lambda[0,0]+Lambda[1,1])/Lambda.trace()*100,"%")
print("The first and the second eigenvalues retain the 99% of the total variability as in the prevoious case without noises" )

fig_2, (plt7, plt8) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
plt7.scatter(data_2[0,:], data_2[2,:], alpha=0.2, color = 'purple')
plt8.scatter(Xp[0,:], Xp[2,:], alpha=0.2, color = 'purple')
plt.ylim((-15,15))
plt7.set_title('(0,2) before rotation')
plt8.set_title('(0,2) after rotation')
plt.show()
# Out:
# Eigenvalue 27.434598000073784 with eigenvector:  [-1.18143696e-01  5.65130232e-01  1.70261379e-04 -4.30528086e-04
#  -8.92654045e-04  9.37830498e-04 -6.80646304e-04  8.82329030e-04
#  -2.77791817e-04  1.08542533e-04  1.40467297e-05 -8.16470924e-01
#  -6.47273693e-03]
#
# Eigenvalue 2.000861219551628 with eigenvector:  [-5.73999472e-01 -7.09823835e-01 -8.71209902e-04  4.90567898e-04
#   1.21258328e-03 -1.55791192e-03  7.32409296e-04 -1.37600234e-03
#   5.73621156e-04 -6.37294400e-04 -1.14771701e-05 -4.08235462e-01
#  -3.23636846e-03]
#
# Eigenvalue 0.02553506564205762 with eigenvector:  [-8.10286865e-01  4.20436628e-01 -5.30687143e-04 -3.70488273e-04
#  -5.72724814e-04  3.17749081e-04 -6.28883312e-04  3.88655725e-04
#   1.80375211e-05 -4.20209333e-04  1.66162893e-05  4.08235462e-01
#   3.23636846e-03]
#
# Eigenvalue 0.02004501613049731 with eigenvector:  [ 2.45032693e-04 -7.52064742e-04 -2.17283947e-02  4.45307669e-02
#   1.03351206e-01 -1.00150781e-01 -9.87671586e-01 -4.10386174e-03
# ...

# %% [markdown]
# 3 \. **Looking at an oscillating spring** (optional)
#
# Imagine you have $n$ cameras looking at a spring oscillating along the $x$ axis. Each  camera record the motion of the spring looking at it along a given direction defined by the pair $(\theta_i, \phi_i)$, the angles in spherical coordinates.
#
# Start from the simulation of the records (say ${\cal O}(1000)$) of the spring's motion along the x axis, assuming a little random noise affects the measurements along the $y$. Rotate such dataset to emulate the records of each camera.
#
# Perform a Principal Component Analysis on the thus obtained dataset, aiming at finding the only one coordinate that really matters.

# %% [markdown]
# 4\. **PCA on the MAGIC dataset** (optional)
#
# Perform a PCA on the magic04.data dataset

# %%
# get the dataset and its description on the proper data directory
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data -P ~/data/
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names -P ~/data/
# Out:
# --2021-12-13 18:14:52--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1477391 (1,4M) [application/x-httpd-php]
# Saving to: ‘/home/ale/data/magic04.data.2’
#
# magic04.data.2      100%[===================>]   1,41M   249KB/s    in 5,8s
#
# 2021-12-13 18:15:01 (249 KB/s) - ‘/home/ale/data/magic04.data.2’ saved [1477391/1477391]
#
# --2021-12-13 18:15:01--  https://archive.ics.uci.edu/ml/machine-learning-databases/magic/magic04.names
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5400 (5,3K) [application/x-httpd-php]
# Saving to: ‘/home/ale/data/magic04.names.2’
# ...
