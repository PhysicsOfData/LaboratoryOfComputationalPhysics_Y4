# %% [markdown]
# 1\. **Hurricanes per Year**
#
# The number of hurricanes in 2005 was 15. The historic average is 6.3. Is this number signficantly different?
# - Assume the number of hurricanes is random, i.e. follows the Poisson distribution.
# - Assume as statistically significant a probability that has a Z score of 3 or larger with respect a normal distribution.
#
# **Hint**: compute the probability that in a single year are observed 15 or more hurricances.

# %%
import numpy as np
from scipy import stats
#mean = varience of poisson distribution  

λ = 6.3 #average event rate
k=15 #number of times an event occurs in an interval

P = (λ**k)*(np.exp(-λ))/np.math.factorial(k)
print(P)

x0 = 15
mu = 6.3
sigma = np.sqrt(mu)

# determine the Z score
Z = abs(x0 - mu) / sigma
print("Z =", Z)
# Out:
# 0.001372629709714795
# Z = 3.4661629670697414

# %% [markdown]
# 2\. **Pairwise t-test**
#
# In an experiment, a group of 10 individuals agreed to participate in a study of blood pressure changes following exposure to halogen lighting. Resting systolic blood pressure was recorded for each individual. The participants were then exposed to 20 minutes in a room lit only by halogen lamps. A post-exposure systolic blood pressure reading was recorded for each individual. The results are presented in the following data set:
#
# ```python
# pre = np.array([120, 132, 120, 110, 115, 128, 120, 112, 110, 100])
# post = np.array([140, 156, 145, 130, 117, 148, 137, 119, 127, 135])
# ```
#
# Determine whether the change in blood pressures within our sample was statistically significant.
#
# **Hint:**
# in this case, the Student's $t$-test should be performed to compare the two datasets.
# Use the following test statistics:
#
# $$T = \frac{\bar{x}_1 - \bar{x}_2}{\sigma \sqrt{\frac{2}{n}}}$$
#
# and
#
# $$\sigma = \sqrt{\frac{\sigma_1^2 + \sigma_2^2}{2}}$$

# %%
pre = np.array([120, 132, 120, 110, 115, 128, 120, 112, 110, 100])
post = np.array([140, 156, 145, 130, 117, 148, 137, 119, 127, 135])

mu_1 = np.mean(pre)
mu_2 = np.mean(post)
std_1 = np.std(pre)
std_2 = np.std(post)
n = len(pre)

std = np.sqrt((std_1**2 + std_2**2)/2) 
T = (std_1 - std_2)/(std*np.sqrt(2/n))

pvalue = stats.t.cdf(T, n - 1) + (1. - stats.t.cdf(-T, n - 1))
print("p-value =", pvalue)
# Out:
# p-value = 0.5403044785184816

# %% [markdown]
# 3\. **FFT of a simple dataset**
#
# Perform a periodicity analysis on the lynxs-hares population, i.e. determine what is the period of the population of these animals.

# %%
import pandas as pd
from scipy import fftpack
import matplotlib.pyplot as plt

df=pd.read_csv('populations.txt', sep = '\t') #'\t' tab seprated varible
df
# Out:
#     # year     hare     lynx  carrot
# 0     1900  30000.0   4000.0   48300
# 1     1901  47200.0   6100.0   48200
# 2     1902  70200.0   9800.0   41500
# 3     1903  77400.0  35200.0   38200
# 4     1904  36300.0  59400.0   40600
# 5     1905  20600.0  41700.0   39800
# 6     1906  18100.0  19000.0   38600
# 7     1907  21400.0  13000.0   42300
# 8     1908  22000.0   8300.0   44500
# 9     1909  25400.0   9100.0   42100
# 10    1910  27100.0   7400.0   46000
# 11    1911  40300.0   8000.0   46800
# 12    1912  57000.0  12300.0   43800
# 13    1913  76600.0  19500.0   40900
# 14    1914  52300.0  45700.0   39400
# 15    1915  19500.0  51100.0   39000
# 16    1916  11200.0  29700.0   36700
# 17    1917   7600.0  15800.0   41800
# 18    1918  14600.0   9700.0   43300
# 19    1919  16200.0  10100.0   41300
# 20    1920  24700.0   8600.0   47300

# %%
plt.figure(figsize = (12,8))
plt.plot(df['# year'], df['hare'], label = "Min", c='blue')
plt.plot(df['# year'], df['lynx'], label = "Min", c='red')

hare_fft = fftpack.fft(df['hare'].values)
lynx_fft = fftpack.fft(df['lynx'].values)

hare_power = np.abs(hare_fft)
lynx_power = np.abs(lynx_fft)

hare_freq = fftpack.fftfreq(len(df['# year']), d=1)
lynx_freq = fftpack.fftfreq(len(df['# year']), d=1)

# Plot the FFT power
plt.figure(figsize=(8, 6))
plt.plot(lynx_freq, lynx_power)
plt.xlabel('Frequency [Hz]')
plt.ylabel('Power')


hare_pos_mask = np.where(hare_freq > 0)
lynx_pos_mask = np.where(lynx_freq > 0)

hare_freqs = hare_freq[hare_pos_mask]
lynx_freqs = lynx_freq[lynx_pos_mask]

hare_powes = hare_power[hare_pos_mask]
lynx_powes = lynx_power[lynx_pos_mask]


hare_peak_freq = hare_freqs[hare_powes.argmax()]
lynx_peak_freq = lynx_freqs[lynx_powes.argmax()]

print(hare_peak_freq)

print(hare_peak_freq)
hare_high_freq_fft = hare_fft.copy()
lynx_high_freq_fft = lynx_fft.copy()
hare_high_freq_fft[np.abs(hare_freq) > hare_peak_freq] = 0
lynx_high_freq_fft[np.abs(lynx_freq) > lynx_peak_freq] = 0

hare_filtered_sig = fftpack.ifft(hare_high_freq_fft)
hare_real_filtered_signal = np.real(hare_filtered_sig)
lynx_filtered_sig = fftpack.ifft(lynx_high_freq_fft)
lynx_real_filtered_signal = np.real(lynx_filtered_sig)

plt.figure(figsize=(8, 6))
plt.plot(df['# year'],df['hare'], alpha=0.5, label='Hare Original signal')
plt.plot(df['# year'], hare_real_filtered_signal, linewidth=3, label=' Hare Filtered signal')
plt.plot(df['# year'],df['lynx'], alpha=0.5, label='Lynx Original signal')
plt.plot(df['# year'], lynx_real_filtered_signal, linewidth=3, label=' Lynx Filtered signal')

plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend(loc='best')


#real_filtered_signal = np.real(filtered_sig)
# Out:
# 0.09523809523809523
# 0.09523809523809523

# %% [markdown]
# 4\. **FFT of an image**
#
# Write a filter that removes the periodic noise from the `moonlanding.png` image by using a 2-dimensional FFT.
#
# * Import the image as a 2D numpy array using `plt.imread("moonlanding.png")`. Examine the image with `plt.imshow()`, which is heavily contaminated with periodic noise.
# * Check the documentation of the `scipy.fftpack` package, and find the method that performs a 2D FFT. Plot the spectrum (Fourier transform of) the image. **Hint**: use `LogNorm` to plot the colors in log scale:
# ```Python
# from matplotlib.colors import LogNorm
# plt.imshow(image, norm=LogNorm(vmin=5))
# ```
# * Inspect the spectrum, and try to locate the regions of the power spectrum that contain the signal and those which contain the periodic noise. Use array slicing to set the noise regions to zero.
# * Apply the inverse Fourier transform to plot the resulting image.

# %%
#https://docs.scipy.org/doc/scipy/reference/fftpack.html?highlight=fftpack#module-scipy.fftpack
from scipy import fft # fftpack is legacy now 
from matplotlib.colors import LogNorm

img= plt.imread("moonlanding.png")

#image = plt.imshow(image, norm=LogNorm(vmin=5))

print(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-9997de08563a> in <module>
#       3 from matplotlib.colors import LogNorm
#       4
# ----> 5 img= plt.imread("moonlanding.png")
#       6 #image = plt.imshow(image, norm=LogNorm(vmin=5))
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2244 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2245 def imread(fname, format=None):
# -> 2246     return matplotlib.image.imread(fname, format)
#    2247
#    2248
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1494                     response = io.BytesIO(response.read())
#    1495                 return imread(response, format=ext)
# -> 1496     with img_open(fname) as image:
#    1497         return (_pil_png_to_float_array(image)
# ...
