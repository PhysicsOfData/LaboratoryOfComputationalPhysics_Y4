# %% [markdown]
# 1\. **2D minimization of a six-hump camelback function**
#
# $$f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2$$
#
# has multiple global and local minima.
#
# - Find the global minima of this function
# - How many global minima are there, and what is the function value at those points?
# - What happens for an initial guess of $(x, y) = (0, 0)$?
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use `numpy.meshgrid()` and `pylab.imshow()` to find visually the regions.
# * Use `scipy.optimize.minimize()`, optionally trying its optional arguments.

# %%
import numpy as np
import pylab
import scipy
from scipy.optimize import minimize 
import matplotlib
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import math
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
#Nelder-Mead method
from scipy.optimize import fmin

def f(x):
    return (4 - 2.1*x[0]**2 + (x[0]**4)/3)*x[0]**2 + x[0]*x[1] + (4*x[1]**2 - 4)*x[1]**2

fmin(f,np.array([0,0]))
# Out:
# Optimization terminated successfully.
#          Current function value: -1.031628
#          Iterations: 52
#          Function evaluations: 101
# array([-0.08985145,  0.71266538])

# %%
def f(x,y):
    return (4 - 2.1*x**2 + (x**4)/3)*x**2 + x*y + (4*y**2 - 4)*y**2

x = np.arange(-2.0,2.0,0.05)
y = np.arange(-1.0,1.0,0.05)
X,Y = np.meshgrid(x, y)
F = f(X, Y)
image = pylab.imshow(F,cmap=pylab.cm.RdBu)
#contour lines with labels and colorbar
cset = pylab.contour(F,np.arange(-1,1.5,0.2),linewidths=1,cmap=pylab.cm.RdBu)
pylab.clabel(cset,inline=True,fmt='%1.1f',fontsize=10)
pylab.colorbar(image)

# %%
x = np.arange(-2.0,2.0,0.05)
y = np.arange(-2.0,2.0,0.05)
minimize(f, 0, 0)
# Out:
#       fun: 0.0
#  hess_inv: array([[1]])
#       jac: array([5.96046448e-08])
#   message: 'Optimization terminated successfully.'
#      nfev: 2
#       nit: 0
#      njev: 1
#    status: 0
#   success: True
#         x: array([0.])

# %% [markdown]
# ##### 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celsius):
#
# max:  `17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18`
#
# min: `-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58`
#
# * Plot these temperatures.
# * Find a suitable a function that can describe min and max temperatures.
# * Fit this function to the data with `scipy.optimize.curve_fit()`.
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
mx=[17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18]
mn=[-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58]
a_list=list(range(1, len(mx)+1))

plt.plot(a_list, mx,marker='o', linestyle='', color='r')
plt.plot(a_list, mn,marker='o', linestyle='', color='b')

plt.legend(["max", "min"])

def guess_f(x, a, b, c, d):
    return a * np.exp(-np.power(x - b, 2.) / (2 * np.power(c, 2.))) - d

#parameters & covariance matrix
popt, pcov = curve_fit(guess_f, a_list, mx)
print(popt)

f_mx = plt.plot(a_list, guess_f(a_list, popt[0], popt[1], popt[2], popt[3]))

print("The fit looks reasonable but I need to check the correlation coefficient")

ssr = sum((guess_f(a_list, popt[0], popt[1], popt[2], popt[3])-mx)**2)
tss = sum((np.mean(mx)-mx)**2)
R = 1 - ssr/tss

print(R)
print("The value is good but it could be better")

phase_max = popt[1]
var1 = tss

def guess_f(x, a, b, c, d):
    return a * np.exp(-np.power(x - b, 2.) / (2 * np.power(c, 2.))) - d

popt, pcov = curve_fit(guess_f, a_list, mn)
print(popt)

f_mn = plt.plot(a_list, guess_f(a_list, popt[0], popt[1], popt[2], popt[3]))

print("The fit looks reasonable but I need to check the correlation coefficient")

ssr = sum((guess_f(a_list, popt[0], popt[1], popt[2], popt[3])-mn)**2)
tss = sum((np.mean(mn)-mn)**2)
R = 1 - ssr/tss

print(R)
print("The value is good but it could be better")

phase_min = popt[1]
var2 = tss

phase_shift = abs(phase_max - phase_min)
var = var1 - var2
if phase_shift < var :
   print('time offset is the same for min and max temperatures within the fit accuracy')
# Out:
# [ 23.09208176   6.73581609  -2.29443446 -15.77932752]
# The fit looks reasonable but I need to check the correlation coefficient
# 0.9858796078364396
# The value is good but it could be better
# [52.64929127  7.16452605 -1.97589994 61.32093394]
# The fit looks reasonable but I need to check the correlation coefficient
# 0.9946041936397112
# The value is good but it could be better

# %% [markdown]
# 3\. **Fit the residues**
#
# Read the `data/residuals_261.pkl` file. If you haven't it already, download it from here:
#
# ```bash
# wget https://www.dropbox.com/s/3uqleyc3wyz52tr/residuals_261.pkl -P data/
# ```
#
# The feature name "residual" contains the residuals (defined as $y_i - \hat{y}_i$) of a linear regression as a function of the independent variable "distances".
#
# - Considering only the "residual" feature, create an histogram with the appropriate binning and display it.
# - Set the appropriate Poisson uncertainty for each bin (thus, for each bin, $\sigma_i = \sqrt{n_i}$, where $n_i$ is the number of entries in each bin)
# - By looking at the distribution of the residuals, define an appropriate function and fit it to the histogram of the residuals
# - Perform a goodness-of-fit test. Is the p-value of the fit satisfactory?

# %%
from scipy.stats import norm

print(pd.read_pickle('residuals_261.pkl'))
df = pd.DataFrame(pd.read_pickle('residuals_261.pkl').item())
#get rid of some data
df = df[df['residuals']>-2.5]
df = df[df['residuals']<2.5]
nbin=100
fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(8,12))
hist = ax[0].hist((df['residuals']), bins=nbin, color='white', edgecolor='red')
bin_heights = hist[0]
#print(hist[0])
bin_edges = hist[1]
bin_centers = 0.5*(bin_edges[1:] + bin_edges[:-1])
ax[0].errorbar(bin_centers, bin_heights, yerr = bin_heights**0.5, drawstyle = "steps-mid", color='green')

def f_gauss(x, mean, std):
    return norm.pdf(x, mean, std)

#popt, _ = curve_fit(f_gauss, bin_centers, bin_heights)
#print(popt)
myfit = norm.fit(df['residuals'])

x_interval_for_fit = np.linspace(bin_edges[0], bin_edges[-1], 10000)
plt.plot(x_interval_for_fit, f_gauss(x_interval_for_fit, myfit[0], myfit[1]))

dof = len(df['residuals']) - 1
chi2 = np.sum(np.square(df['residuals'] - np.mean(df['residuals'])))/np.square(myfit[1])
pvalue = 1. - scipy.stats.chi2.cdf(chi2, dof)
print('p-value', pvalue)
# Out:
# {'residuals': array([ 1.1       , -1.95      , -7.2       , ...,  0.08333333,
#         0.16666667,  0.08333333]), 'distances': array([16. ,  6.3,  3.4, ...,  1.7, 19.1,  2.6])}
# p-value 0.495435120781172

# %% [markdown]
# 4\. **Temperatures in Munich**
#
# Get the following data file:
#
# ```bash
# https://www.dropbox.com/s/7gy9yjl00ymxb8h/munich_temperatures_average_with_bad_data.txt
# ```
#
# which gives the temperature in Munich every day for several years.
#
#
# Fit the following function to the data:
#
# $$f(t) = a \cos(2\pi t + b)+c$$
#
# where $t$ is the time in years.
#
# - Make a plot of the data and the best-fit model in the range 2008 to 2012.
#
#    - What are the best-fit values of the parameters?
#
#    - What is the overall average temperature in Munich, and what are the typical daily average values predicted by the model for the coldest and hottest time of year?
#
#    - What is the meaning of the $b$ parameter, and what physical sense does it have?
#
#
# - Now fit the data with the function $g(x)$, which has 1 more parameter than $f(x)$.
# $$g(x) = a \cos(2\pi b t + c)+d$$
#    - What are the RSS for $f(x)$ and $g(x)$?
#    - Use the Fisher F-test to determine whether the additional parameter is necessary.

# %%
date, temperature = np.loadtxt('munich_temperatures_average_with_bad_data.txt', unpack=True)
plt.plot(date, temperature, '.')
def cos(x, a, b, c):
    return a * np.cos(2 * np.pi * x + b) + c
popt, pcov = curve_fit(cos, date, temperature)
x = np.linspace(2008, 2012, 100)
plt.plot(x, cos(x, *popt), color='red', linewidth=2)
matplotlib.pyplot.show()

print(popt)
print('Average temperature in Munich', np.mean(temperature))
print('Average temperature by the model', np.mean(cos(temperature,*popt)))

y1=cos(temperature,*popt)
ssr1 = np.sum(( y1- temperature)**2)
print('The RSS',ssr1)
#there are some bad data!
#b parameter influences the period of the cosine function so it makes the model to fit the seasonal cycle

plt.plot(date, temperature, '.')
def cos(x, a, b, c, d):
    return a * np.cos(2 * np.pi * x * d + b) + c
popt, pcov = curve_fit(cos, date, temperature)
plt.plot(x, cos(x, *popt), color='orange', linewidth=2)
print(popt)

def Ftest(ssr_1, ssr_2, ndof_1, ndof_2, nbins, verbose=False):
    F = ((ssr_1 - ssr_2)/(ndof_2 - ndof_1)) / (ssr_2/(nbins - ndof_2))
    CL = 1. - scipy.stats.f.cdf(F, ndof_2 - ndof_1, nbins - ndof_2)
    if verbose: print("CL: %.3f" % CL, ", additional parameter necessary:", "yes" if CL < 0.10 else "no")
    return CL

y2=cos(temperature,*popt)
ssr2 = np.sum(( y2- temperature)**2)
print('The RSS',ssr2)

CL=Ftest(ssr1,ssr2,3,4,len(temperature))
print(CL)
# Out:
# [-9.67127679 12.34271735  9.0525621 ]
# Average temperature in Munich 8.941907038598593
# Average temperature by the model 8.940561415747517
# The RSS 1336026.1352070512
# [-9.67155083 15.62348314  9.05135173  0.99973948]
# The RSS 1310785.2932257745
# 1.1102230246251565e-16
