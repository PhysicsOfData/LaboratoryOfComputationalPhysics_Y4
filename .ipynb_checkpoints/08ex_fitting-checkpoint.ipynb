# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from scipy.stats import linregress
from scipy.integrate import trapz
from matplotlib.ticker import AutoMinorLocator, MultipleLocator, FuncFormatter
import math
import scipy
from scipy import optimize
from scipy.stats import poisson
# %matplotlib inline
from scipy import stats
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import ScalarFormatter
import matplotlib

# %% [markdown]
# 1\. **2D minimization of a six-hump camelback function**
#
# $$f(x,y) = \left(4-2.1x^2+\frac{x^4}{3} \right) x^2 +xy + (4y^2 -4)y^2$$
#
# has multiple global and local minima.
#
# - Find the global minima of this function
# - How many global minima are there, and what is the function value at those points?
# - What happens for an initial guess of $(x, y) = (0, 0)$?
#
# Hints:
#
# * Variables can be restricted to $-2 < x < 2$ and $-1 < y < 1$.
# * Use `numpy.meshgrid()` and `pylab.imshow()` to find visually the regions.
# * Use `scipy.optimize.minimize()`, optionally trying its optional arguments.

# %%
def function(x):
    return ((4 - 2.1*pow(x[0],2) + pow(x[0], 4)/3 )*pow(x[0],2) + x[0]*x[1] +(4*pow(x[1],2) - 4)*pow(x[1],2))

plus = np.array([(0.5, 0), (0.75, 0), (1, 0), (0, 0.5), (0, 0.75), (1,1), (0,0)])
#minus = -1*plus
minus = np.array([(-0.5, 0), (-0.75, 0), (-1, 0), (0, -0.5), (0, -0.75), (-1,-1), (0,0)])

#exploring
methods = ["Powell", "BFGS", "L-BFGS-B", "SLSQP", "Nelder-Mead", "COBYLA"]
for x0plus, x0minus in zip(plus, minus):
    xmplus = [optimize.minimize(function, x0plus, method = m) for m in methods]
    xmminus = [optimize.minimize(function, x0minus, method = m) for m in methods]
    print("\nUsing the stating points {} and {}:".format(x0plus, x0minus))
    for meth, xplus, xminus in zip(methods, xmplus, xmminus):
        print("Using the algorithm {} the minima found are: {}, {}".format(meth, xplus.x, xminus.x))

xmin = optimize.minimize(function, (1,1), method = "Powell")
xmin2 = optimize.minimize(function, (0,0), method = "Powell")

x = np.linspace(-2, 2, 100)
y = np.linspace(-1, 1, 100)
g = np.meshgrid(x, y)
z = function(g)

fig, ax = plt.subplots(figsize=(13, 5))
im = ax.imshow(z, extent=[-2, 2, -1, 1])
plt.colorbar(im)
ax.scatter(xmin.x[0], xmin.x[1], color = "red")
ax.scatter(xmin2.x[0], xmin2.x[1], color = "red")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("Function color map")
plt.show()


fig = plt.figure(figsize=(10, 10))
ax = plt.axes(projection="3d")
ax.plot_surface(g[0], g[1], z, cmap = plt.cm.jet)
ax.set_xlabel("x", fontsize = 18)
ax.set_ylabel("y", fontsize = 18)
ax.set_zlabel("z", fontsize = 18)
ax.set_title("3D function plot", fontsize = 18)
plt.show()
# Out:
# Using the stating points [0.5 0. ] and [-0.5  0. ]:
# Using the algorithm Powell the minima found are: [ 0.08984201 -0.71265634], [-0.08984201  0.71265634]
# Using the algorithm BFGS the minima found are: [ 0.08984201 -0.71265641], [-0.08984202  0.7126564 ]
# Using the algorithm L-BFGS-B the minima found are: [ 0.08984196 -0.71265666], [-0.08984197  0.71265665]
# Using the algorithm SLSQP the minima found are: [ 0.08980396 -0.71279319], [-0.08980397  0.71279317]
# Using the algorithm Nelder-Mead the minima found are: [-0.08982696  0.71267666], [-0.08988091  0.71267098]
# Using the algorithm COBYLA the minima found are: [ 0.0898385  -0.71257557], [-0.089794    0.71270176]
#
# Using the stating points [0.75 0.  ] and [-0.75  0.  ]:
# Using the algorithm Powell the minima found are: [-0.08984201  0.71265634], [ 0.08984201 -0.71265634]
# Using the algorithm BFGS the minima found are: [ 0.08984203 -0.71265647], [-0.08984204  0.71265645]
# ...

# %% [markdown]
# **comment**:
#
# THe function has two global minima. The different algorithms can always find one of the two minima from a given point different from (0,0).
# (0,0) is a saddle point, and the default algorithms cannot find a global minimum starting from that point. Different algorithms however, such as Powell, Nelder-Mead and Cobyla, are able to find one of the minima.

# %% [markdown]
# 2\. **Curve fitting of temperature in Alaska**
#
# The temperature extremes in Alaska for each month, starting in January, are given by (in degrees Celcius):
#
# max:  `17,  19,  21,  28,  33,  38, 37,  37,  31,  23,  19,  18`
#
# min: `-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58`
#
# * Plot these temperatures.
# * Find a suitable a function that can describe min and max temperatures.
# * Fit this function to the data with `scipy.optimize.curve_fit()`.
# * Plot the result. Is the fit reasonable? If not, why?
# * Is the time offset for min and max temperatures the same within the fit accuracy?

# %%
def funcfit(t, a, b, c, d):
    return a*np.sin((t+b)*c) + d

months = np.arange(12)
maxt = np.array([17, 19, 21, 28, 33, 38, 37, 37, 31, 23, 19, 18])
mint = np.array([-62, -59, -56, -46, -32, -18, -9, -13, -25, -46, -52, -58])

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(months, maxt, "ro", label = "max_temp")
ax.plot(months, mint, "bo", label = "min_temp")
ax.set_xlabel("month")
ax.set_ylabel("temperature")

#maximum
maxpars, maxcov = optimize.curve_fit(funcfit, months, maxt, [20, 1, 0.1, 20])

#minimum
minpars, mincov = optimize.curve_fit(funcfit, months, mint, [40, 1, 0.1, -40])
print(maxpars, '\n')
print(minpars, '\n')
print("period maximum temperature (months): %.3f" %(2*math.pi/maxpars[2]),
      " period minimum temperature (months): %.3f " %(2*math.pi/minpars[2]))

days = np.linspace(0, 12, 365)
ax.plot(days, funcfit(days, *maxpars), "orange", label = "fit max t")    
ax.plot(days, funcfit(days, *minpars), "lightblue",  label = "fit min t")
ax.legend()
plt.show()

offset1, var1 = maxpars[1], maxcov[1,1]
offset2, var2 = minpars[1], mincov[1,1]
accuracy = abs(offset1 - offset2)/ (np.sqrt(var1+var2))
print("compatibility between offsets: %.3f" %accuracy)

#goodness of fit
ssrmax = np.sum((maxt - funcfit(months, *maxpars))**2)
ssrmin = np.sum((mint - funcfit(months, *minpars))**2)

tssmax = np.sum((maxt - np.mean(maxt))**2)
tssmin = np.sum((mint - np.mean(mint))**2)

r2max = 1. - (ssrmax/tssmax)
r2min = 1. - (ssrmin/tssmin)

print("\nR^2 for maximum temperature / minimum temperature: {} / {} ".format(r2max, r2min))
# Out:
# [10.58169953 -3.07063123  0.59227424 27.94963543]
#
# [ 25.14961944  -3.52075249   0.60132118 -36.71255702]
#
# period maximum temperature (months): 10.609  period minimum temperature (months): 10.449
# compatibility between offsets: 2.638
#
# R^2 for maximum temperature / minimum temperature: 0.9882502430477917 / 0.9787202745532558

# %% [markdown]
# **comment**:
#
# I chose the sine function since I suppose that the temperature oscillates in a similar way every year. The period of the fitted sine wave is indeed approximately 10.5 months.
#
# I added the parameters to the function corresponding to a shift in the average value, an amplitude, an offset and the frequency.
#
# The fit is reasonable, to have the same temperature oscillations every year the period should be exactly 12 months otherwise there would be a shift, bit the model is good.
#
# We can see as expected that the maximum is in june for both the curves.

# %% [markdown]
# 3\. **Fit the residues**
#
# Read the `data/residuals_261.pkl` file. If you haven't it already, download it from here:
#
# ```bash
# wget https://www.dropbox.com/s/3uqleyc3wyz52tr/residuals_261.pkl -P data/
# ```
#
# The feature name "residual" contains the residuals (defined as $y_i - \hat{y}_i$) of a linear regression as a function of the independent variable "distances".
#
# - Considering only the "residual" feature, create an histogram with the appropriate binning and display it.
# - Set the appropriate Poisson uncertainty for each bin (thus, for each bin, $\sigma_i = \sqrt{n_i}$, where $n_i$ is the number of entries in each bin)
# - By looking at the distribution of the residuals, define an appropriate function and fit it to the histogram of the residuals
# - Perform a goodness-of-fit test. Is the p-value of the fit satisfactory?

# %%
#!wget https://www.dropbox.com/s/hgnvyj9abatk8g6/residuals_261.pkl

data = np.load("residuals_261.pkl", allow_pickle = True)
dd= pd.DataFrame(data.item())


minn = dd["residuals"].min()
maxx = dd["residuals"].max()

fig, ax = plt.subplots(figsize=(10, 5))
counts, edges, patches = ax.hist(dd["residuals"], bins = int(np.sqrt(len(dd["residuals"]))), color = "orange" , alpha = 0.5)
ax.set_ylabel("Counts")
plt.show()

neg = -dd[dd["residuals"] < 0]


fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(15, 5))
hist, bins, _ = ax1.hist(neg["residuals"], bins=int(np.sqrt(len(neg["residuals"]))))
ax1.set_title("Representation of negative part of the histogram\n (x axis becomes positive)")
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins), base = 10)
cts, bins, _ = ax2.hist(dd["residuals"], bins = logbins, color = "orange", alpha = 0.5)
ax2.set_title("Logscale representation of negative part of the histogram\n (x axis becomes positive)")
ax2.set_xscale("log")
plt.show()


fig, ax = plt.subplots(figsize=(10, 5))
counts, edges, patches = ax.hist(dd["residuals"], bins = int(np.sqrt(len(abs(dd["residuals"]) < 4))), range=(-4,4), color = "orange" , alpha = 0.5, edgecolor = "black") #int(dd.shape[0]/800)
binwidth = edges[1] - edges[0]
bin_centres = (edges[:-1] + edges[1:]) / 2
y_error = np.sqrt(counts) # poissonian error
ax.errorbar(x = bin_centres, y = counts, yerr = y_error, fmt = "none", color = "black", alpha = 0.5)
ax.set_ylabel("Counts")
ax.set_title("Histogram of values, Poisson error bars")


def gauss(x, A , mu , sigma):
    return A*np.exp(-((x - mu)**2) /(2*sigma**2))


idx = [i for i in range (len(bin_centres)) if bin_centres[i] >= -2.5 and bin_centres[i] <= 2.5]
xbins = bin_centres[idx]
ycounts = counts[idx]
errors = y_error[idx]
print("outliers (|bin center coordinate| > {} ): {} ".format(2.5, counts.sum() - ycounts.sum()))

params, covm = optimize.curve_fit(gauss, xbins, ycounts, p0=[2500, 0, 1])
ax.plot(xbins, gauss(xbins, *params), color = "black", label = "Fitted curve, Gaussian")
plt.legend()
plt.show()

p = np.arange(0,2000,1)
ndof = len(xbins) - 3
print("n degrees of freedom = ", ndof)

# calculate the chi^2
chi2 = np.sum(((ycounts - gauss(xbins, *params))**2) / errors**2)
print("chi2 =", chi2)
# calculate the p-value from the chi^2, the n.d.o.f., and the comulative chi^2 distribution
pvalue = 1. - stats.chi2.cdf(chi2, ndof)
print("p-value =", pvalue) # if the p-value is < 0.05, the fit is considered unsatisfactory


plt.plot(p, stats.chi2.cdf(p, df=ndof))
plt.fill_between(xbins, ycounts, where=(xbins > chi2), color= "lightblue")
plt.axvline(chi2, color='r')
plt.show()
# Out:
# outliers (|bin center coordinate| > 2.5 ): 190.0
# n degrees of freedom =  62
# chi2 = 1468.0019382383202
# p-value = 0.0

# %% [markdown]
# **comment**:
#
# Looking at the data and at the logscale plot, we can see that the majority of the data has $ |x| < 1 $. Setting the threshold to 2.5, we see that there are O(100) residuals being farther than 2.5 from 0. We can then analyize separately the center and the tail of the data distribution, and perform a fit on the data centered on 0.
#
#
# I used a gaussian to fit the data, but the p value is too high: we have to reject the hypothesis, remembering $$p = \int_F^{+\infty} \mathcal{f(x)} d\mathcal{x}$$ with F being the threshold. Moreover the $\chi^2$ value (even normalized) is too high to be reliable for predictions.

# %% [markdown]
# 4\. **Temperatures in Munich**
#
# Get the following data file:
#
# ```bash
# https://www.dropbox.com/s/7gy9yjl00ymxb8h/munich_temperatures_average_with_bad_data.txt
# ```
#
# which gives the temperature in Munich every day for several years.
#
#
# Fit the following function to the data:
#
# $$f(t) = a \cos(2\pi t + b)+c$$
#
# where $t$ is the time in years.
#
# - Make a plot of the data and the best-fit model in the range 2008 to 2012.
#
#    - What are the best-fit values of the parameters?
#
#    - What is the overall average temperature in Munich, and what are the typical daily average values predicted by the model for the coldest and hottest time of year?
#
#    - What is the meaning of the $b$ parameter, and what physical sense does it have?
#
#
# - Now fit the data with the function $g(x)$, which has 1 more parameter than $f(x)$.
# $$g(x) = a \cos(2\pi b t + c)+d$$
#    - What are the RSS for $f(x)$ and $g(x)$?
#    - Use the Fisher F-test to determine whether the additional parameter is necessary.

# %%
#!wget https://www.dropbox.com/s/7gy9yjl00ymxb8h/munich_temperatures_average_with_bad_data.txt

def f(t, a, b, c):
    return a*np.cos(2*np.pi*t+b)+c

def g(t, a, b, c, d):
    return a*np.cos(2*np.pi*b*t+c)+d


data = np.loadtxt("munich_temperatures_average_with_bad_data.txt", unpack=True)
date, temp = data[0], data[1]

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(15, 5))
ax1.plot(date, temp, color = "orange")
ax1.set_xlabel("year")
ax1.set_ylabel("temperature")
ax1.set_title("Temperature in the years with outliers")

#eliminate outliers
idx = np.abs(temp) < 50
date = date[idx]
temp = temp[idx]

#restrict dataset to 2008-2012
idx = [i for i in range(len(date)) if date[i] >= 2008 and date[i] <= 2012]
date = date[idx]
temp = temp[idx]

param, covm = optimize.curve_fit(f, date, temp)
paramg, covmg = optimize.curve_fit(g, date, temp)

ax2.plot(date, temp, color = "orange")
ax2.plot(date, f(date,*param), color = "red", lw = 3)
#ax2.set_xlim(2008, 2012)
ax2.set_xlabel("year")
ax2.set_ylabel("temperature")
ax2.set_title("Temperature from 2008 to 2012 and fit")
plt.show()

print("a = ", param[0], " b = ", param[1], " c = ", param[2])
print("minimum / maximum temperature predicted: ", param[0] + param[2], " / ",  -param[0] + param[2])

#meaning of b
phase = (4*np.pi-param[1])
print("the minimum temperature of the year is predicted ", round(365*phase/(2*np.pi)), "days after New Year")


ssr = np.sum((temp - f(date, *param))**2)
ssrg = np.sum((temp - g(date, *paramg))**2)
print("ssr for f: ", ssr, "\nssr for g: ", ssrg)

print("\nTest additional parameter:")

def Ftest(ssr_1, ssr_2, ndof_1, ndof_2, nbins, verbose=False):
    F = ((ssr_1 - ssr_2)/(ndof_2 - ndof_1)) / (ssr_2/(nbins - ndof_2))
    CL = 1. - stats.f.cdf(F, ndof_2 - ndof_1, nbins - ndof_2)
    if verbose: print("CL: %.3f" % CL, ", additional parameter necessary:", "YES" if CL < 0.10 else "NO")
    return CL


CLfg = Ftest(ssr , ssrg , 3-1 , 4-1 , len(date) , verbose=True)
# Out:
# a =  -9.962034674335492  b =  12.331742861627047  c =  9.262821311193276
# minimum / maximum temperature predicted:  -0.6992133631422153  /  19.22485598552877
# the minimum temperature of the year is predicted  14.0 days after New Year
# ssr for f:  18669.515394578364
# ssr for g:  18669.225431069353
#
# Test additional parameter:
# CL: 0.880 , additional parameter necessary: NO
