# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import numpy.random as npr
import math

# %% [markdown]
# 1\. **Radioactive decay chain**
#
# ${\rm Tl}^{208}$ decays to ${\rm Pb}^{208}$ with a half-lieve of 3.052 minutes. Suppose to start with a sample of 1000 Thallium atoms and 0 of Lead atoms.
#
# * Take steps in time of 1 second and at each time-step decide whether each Tl atom has decayed or not, accordingly to the probability $p(t)=1-2^{-t/\tau}$. Subtract the total number of Tl atoms that decayed at each step from the Tl sample and add them to the Lead one. Plot the evolution of the two sets as a function of time
# * Repeat the exercise by means of the inverse transform method: draw 1000 random numbers from the non-uniform probability distribution $p(t)=2^{-t/\tau}\frac{\ln 2}{\tau}$ to represent the times of decay of the 1000 Tl atoms. Make a plot showing the number of atoms that have not decayed as a function of time

# %%
#1
npr.seed(123)
t=np.arange(0,1000,1)
tau=3.052*60
p_Tl=1-2**(-t/tau)
n_unif=npr.rand(1000)
n_Tl = np.zeros(len(t))
n_Pb = np.zeros(len(t))
n_Tl[0]=1000
n_Pb[0]=0

for i in range(1,len(t)):
    n_Tl[i]=len(n_unif[n_unif > p_Tl[i]])
    n_Pb[i]=len(n_unif[n_unif < p_Tl[i]])

fig, ax = plt.subplots(figsize=(12,7))

ax.plot(t, n_Tl, label='Tl atoms')
ax.plot(t, n_Pb, label='Pb atoms')
ax.grid(ls='--')
ax.set_title("First method")
ax.set_xlabel("Time [s]")
ax.set_ylabel("Number of atoms")
ax.legend()

#2
z = npr.random(1000) 
t_dec = -tau*np.log2(1-z)


for i in range(1,len(t)):
    n_Tl[i]=len(t_dec[t_dec > t[i]])
    n_Pb[i]=len(t_dec[t_dec < t[i]])
    
fig1, ax1=plt.subplots(figsize=(12,7))
ax1.plot(t, n_Tl, label='Tl atoms')
ax1.plot(t, n_Pb, label='Pb atoms')
ax1.grid(ls='--')
ax1.set_title("Second method")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Number of atoms")
ax1.legend();

# %% [markdown]
# 2\. **Rutherford Scattering**
#
# The scattering angle $\theta$ of $\alpha$ particles hitting a positively charged nucleus of a Gold atom ($Z=79$) follows the rule:
#
# $$
# \tan{\frac{1}{2} \theta} = \frac{Z e^2} {2\pi \epsilon_0 E b}
# $$
#
# where $E=7.7$ MeV and $b$ beam is the impact parameter. The beam is represented by a 2D gaussian distribution with $\sigma=a_0/100$ for both coordinates ($a_0$ being the Bohr radius). Assume 1 million $\alpha$ particles are shot on the gold atom.
#
# Computing the fraction of particles that "bounce back",i.e. those particle whose scattering angle is greater than $\pi/2$ (which set a condition on the impact parameter $b$)

# %%
import scipy.constants as const
Z=79
E=7.7e6*const.e
fact=Z*const.e**2/(2*math.pi*const.epsilon_0*E)


sig=const.physical_constants["Bohr radius"][0]/100
b_cov=np.array([[sig**2,0],[0,sig**2]])

b=npr.multivariate_normal((0,0),b_cov,10**6)  #2D gaussian distribution

b=np.sqrt(b[:,0]**2+b[:,1]**2)
frac=len(b[b<fact])/10**6
print("The fraction of particles that bounce back is: {:.3f} %".format(frac*100))
# Out:
# The fraction of particles that bounce back is: 0.152 %

# %% [markdown]
# 3\. **Monte Carlo integration: hit/miss vs mean value method**
#
# Consider the function
#
# $$f(x) =\sin^2{\frac{1}{x(2-x)}}$$
#
# * Compute the integral of $f(x)$ between 0 and 2 with the hit/miss method. Evaluate the error of your estimate
# * Repeat the integral with the mean value method. Evaluate the error and compare it with the previous one

# %%
def f(x):
    return (np.sin(1/(x*(2-x))))**2

N=1000000

#con cosa va valutato l'errore??

#1
count=0
for i in range(N):
    x=2*npr.random()
    y=npr.random()
    if y<f(x): count+=1
I1=2*count/N
p=count/N
sig1=2*np.sqrt(p/((1-p)*N))
print("The integral evaluated with the hit/miss method is: {:.3f} +- {:.3f}".format(I1, sig1))

#2
x=2*np.random.random(N)
I2=2*np.sum(f(x))/N
sig2=2*np.sqrt(np.var(f(x))/N)
print("The integral evaluated with the mean value method is: {:.4f} +- {:.4f}".format(I2, sig2))
# Out:
# The integral evaluated with the hit/miss method is: 1.452 +- 0.003
# The integral evaluated with the mean value method is: 1.4508 +- 0.0005

# %% [markdown]
# 4\. **Monte Carlo integration in high dimension**
#
# * Start of by computing the area of a circle of unit radius, by integrating the function
#
# $$
# f(x,y)=
# \left\{
# \begin{array}{ll}
#       1 & x^2+y^2\le 1 \\
#       0 & {\rm elsewhere}
# \end{array}
# \right.
# $$
#
# * Generalize the result for a 10D sphere

# %%
def f(x):
    x=x**2
    if np.sum(x)<=1: f=1
    else: f=0
    return f
        

n_dim=10 #generalization for n_dimensions
    

N=5000000
count=0
x=-1+2*npr.rand(n_dim,N)

for i in range(N):
    y=npr.random()
    if y<f(x[:,i]): count+=1
I1=(2**n_dim)*count/N
print("The volume of an {}-dimensional sphere is: {}".format(n_dim,I1))
# Out:
# The volume of an 10-dimensional sphere is: 2.4887296

# %% [markdown]
# 5\. **Monte Carlo integration with importance sampling**
#
# Calculate the value of the integral:
#
# $$
# I=\int_0^1 \frac{x^{-1/2}}{e^x+1} dx
# $$
#
# using the importance sampling method with $w(x)=1/\sqrt{x}$. You should get a result about 0.84

# %%
def f(x):
    return (x**(-1/2))/(np.exp(x)+1)


def w(x):
    return 1/np.sqrt(x)

def iw(a,b):
    return 2*(np.sqrt(b)-np.sqrt(a))

N=100000000
x00=1e-8
x01=1
x0=(npr.random(N))**2
I0=(1./N)*np.sum(f(x0)/w(x0))*iw(x00,x01)

print("The integral evaluated with the importance sampling method is: {:.2f}".format(I0))
# Out:
# The integral evaluated with the importance sampling method is: 0.84
